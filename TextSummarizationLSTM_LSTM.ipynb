# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/UTM/Master Project/'
# Out:
# /content/drive/MyDrive/UTM/Master Project

# %%
import numpy as np
import pandas as pd 
import re
from keras.preprocessing.text import Tokenizer 
from nltk import download
download('stopwords')
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
from attention import AttentionLayer
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df_1 = pd.read_csv('news_summary_more.csv')
df_2 = pd.read_csv('Reviews.csv')

# %% [markdown]
# **Drop unnecessary columns**

# %%
df_2 = df_2.drop(columns=['Id','ProductId','UserId','ProfileName','HelpfulnessNumerator','HelpfulnessDenominator','Score','Time'])
# df_2 = df_2.iloc[:101599,:]
df_2.head()
# Out:
#                  Summary                                                                                                                                                                                                     Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labr...
# 1      Not as Advertised           Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# 2  "Delight" says it all  This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with ...
# 3         Cough Medicine  If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The fl...
# 4            Great taffy                                                             Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.

# %%
df_1 =  df_1.rename(columns={'headlines':'headlines','text':'text'})
df_2 = df_2.rename(columns={'Summary':'headlines', 'Text':'text'})

# %% [markdown]
# ## **Append dataframe 1 and 2**

# %%
from sklearn.utils import shuffle

# %%
reviews = df_1.append(df_2, ignore_index=True)
reviews = shuffle(reviews)
reviews.head()
print('No. of rows after being appended:', reviews.shape)
# Out:
# No. of rows after being appended: (666855, 2)

# %%
# Check for any nulls values
print(reviews.isnull().sum())
print(reviews.shape)
# Out:
# headlines    27
# text          0
# dtype: int64
# (666855, 2)

# %% [markdown]
# # **Handling missing value**

# %%
reviews = reviews.dropna()
reviews = reviews.reset_index(drop=True)
reviews.isnull().sum()

reviews.drop_duplicates(subset=['text'],inplace=True)  #dropping duplicates
reviews.shape
# Out:
# (491936, 2)

# %%
reviews = shuffle(reviews)
reviews = reviews.iloc[:150000,:]
reviews.head()
# Out:
#                                                       headlines                                                                                                                                                                                                     text
# 0                                              Shipping Charges                                                                                   The product was fine, but the cost of shipping was more than the cost<br />of the tea.  Won't make that mistake again.
# 1  Apple to shut down its photo printing service after 16 years  Technology major Apple is planning to shut down its 'Photo Print Products' service after 16 years, the company has confirmed. Launched in 2002, the service let users order albums, photo books, pri...
# 2     Aus woman to try non-stop swim in English Channel 4 times  Thirty-two-year-old Australian ultra-marathon swimmer Chloe McCardel will become the first person to attempt a non-stop quadruple crossing of the English Channel this month. McCardel, who is one o...
# 3                                                     Very Good                                  My 90lbs pure Lab gets his one meal in this. He works on it till he eats the last piece of his kibble. This toy makes him tired, which we need if we are not at home :)
# 4                                                    Easy Peasy  Love the decaffeinated version of Lipton's Cold Brew but hated driving all over trying to find it in the stores.  Soooo much easier to order online!  Quick delivery, right to my door and no tax!  ...

# %%
# let's inspect some reviews
for i in range(5):
    print("Review: ",i+1)
    print(reviews.headlines[i])
    print('-'*80)
    print(reviews.text[i])
    print()
# Out:
# Review:  1
# Shipping Charges
# --------------------------------------------------------------------------------
# The product was fine, but the cost of shipping was more than the cost<br />of the tea.  Won't make that mistake again.
#
# Review:  2
# Apple to shut down its photo printing service after 16 years
# --------------------------------------------------------------------------------
# Technology major Apple is planning to shut down its 'Photo Print Products' service after 16 years, the company has confirmed. Launched in 2002, the service let users order albums, photo books, prints, and other items featuring pictures in Photos. According to a pop-up message in Photos app, the service will end at the end of September this year.
#
# Review:  3
# Aus woman to try non-stop swim in English Channel 4 times
# --------------------------------------------------------------------------------
# Thirty-two-year-old Australian ultra-marathon swimmer Chloe McCardel will become the first person to attempt a non-stop quadruple crossing of the English Channel this month. McCardel, who is one of the four people to complete a triple crossing of the icy channel, will take 45 hours for the 136-kilometre swim. The water body contains a lot of flesh-eating sea fleas and sharks.
#
# Review:  4
# Very Good
# --------------------------------------------------------------------------------
# My 90lbs pure Lab gets his one meal in this. He works on it till he eats the last piece of his kibble. This toy makes him tired, which we need if we are not at home :)
#
# Review:  5
# Easy Peasy
# --------------------------------------------------------------------------------
# Love the decaffeinated version of Lipton's Cold Brew but hated driving all over trying to find it in the stores.  Soooo much easier to order online!  Quick delivery, right to my door and no tax!  Bliss!!!

# %%
# Check for any nulls values
reviews.isnull().sum()
# Out:
# headlines    0
# text         0
# dtype: int64

# %%
# let's inspect some reviews
for i in range(5):
    print("Review: ",i+1)
    print(reviews.headlines[i])
    print('-'*80)
    print(reviews.text[i])
    print()
# Out:
# Review:  1
# Shipping Charges
# --------------------------------------------------------------------------------
# The product was fine, but the cost of shipping was more than the cost<br />of the tea.  Won't make that mistake again.
#
# Review:  2
# Apple to shut down its photo printing service after 16 years
# --------------------------------------------------------------------------------
# Technology major Apple is planning to shut down its 'Photo Print Products' service after 16 years, the company has confirmed. Launched in 2002, the service let users order albums, photo books, prints, and other items featuring pictures in Photos. According to a pop-up message in Photos app, the service will end at the end of September this year.
#
# Review:  3
# Aus woman to try non-stop swim in English Channel 4 times
# --------------------------------------------------------------------------------
# Thirty-two-year-old Australian ultra-marathon swimmer Chloe McCardel will become the first person to attempt a non-stop quadruple crossing of the English Channel this month. McCardel, who is one of the four people to complete a triple crossing of the icy channel, will take 45 hours for the 136-kilometre swim. The water body contains a lot of flesh-eating sea fleas and sharks.
#
# Review:  4
# Very Good
# --------------------------------------------------------------------------------
# My 90lbs pure Lab gets his one meal in this. He works on it till he eats the last piece of his kibble. This toy makes him tired, which we need if we are not at home :)
#
# Review:  5
# Easy Peasy
# --------------------------------------------------------------------------------
# Love the decaffeinated version of Lipton's Cold Brew but hated driving all over trying to find it in the stores.  Soooo much easier to order online!  Quick delivery, right to my door and no tax!  Bliss!!!

# %% [markdown]
# # Lets cleaned datasets

# %%
CURRENCIES = {
    "$": "USD", "zł": "PLN", "£": "GBP", "¥": "JPY", "฿": "THB", "₡": "CRC", "₦": "NGN","₩": "KRW",
    "₪": "ILS", "₫": "VND", "€": "EUR", "₱": "PHP", "₲": "PYG", "₴": "UAH", "₹": "INR",}
CURRENCY_REGEX = re.compile(
    "({})+".format("|".join(re.escape(c) for c in CURRENCIES.keys())))

EMAIL_REGEX = re.compile(
    r"(?:^|(?<=[^\w@.)]))([\w+-](\.(?!\.))?)*?[\w+-]@(?:\w-?)*?\w+(\.([a-z]{2,})){1,3}(?:$|(?=\b))",
    flags=re.IGNORECASE | re.UNICODE,)

# A list of contractions from http://stackoverflow.com/questions/19790188/expanding-english-language-contractions-in-python
contractions =          {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have", "i've": "i have"}

# %%
def clean_text(text, remove_stopwords = True):
    
    text = text.lower()
    if True:
        text = text.split()
        new_text = []
        for word in text:
            if word in contractions:
                new_text.append(contractions[word])
            else:
                new_text.append(word)
        text = " ".join(new_text)
        
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
    text = EMAIL_REGEX.sub(' ',text)
    text = CURRENCY_REGEX.sub(' ',text)
    text = ' '.join([contractions[t] if t in contractions else t for t in text.split(" ")])    
    text = re.sub(r'[_"\-;%()|+&=*%.,!?:#$@\[\]/]', ' ', text)
    text = re.sub(r"'s\b","", text)
    text = re.sub(r'&amp;', '', text) 
    
    if remove_stopwords:
        text = text.split()
        stops = set(stopwords.words("english"))
        text = [w for w in text if not w in stops]
        text = " ".join(text)

    return text

# %%
cleaned_headlines = []
cleaned_text = []

for headlines in reviews['headlines']:
    cleaned_headlines.append(clean_text(headlines, remove_stopwords=False))
print("Headlines are complete.")

for text in reviews['text']:
    cleaned_text.append(clean_text(text))
print("Texts are complete.")
# Out:
# Headlines are complete.
# Texts are complete.

# %%
# let's inspect some clean reviews
for i in range(4):
    print("Review: ",i+1)
    print(cleaned_headlines[i])
    print('-'*80)
    print(cleaned_text[i])
    print()
# Out:
# Review:  1
# shipping charges
# --------------------------------------------------------------------------------
# product fine cost shipping cost<br >of tea make mistake
#
# Review:  2
# apple to shut down its photo printing service after 16 years
# --------------------------------------------------------------------------------
# technology major apple planning shut 'photo print products' service 16 years company confirmed launched 2002 service let users order albums photo books prints items featuring pictures photos according pop message photos app service end end september year
#
# Review:  3
# aus woman to try non stop swim in english channel 4 times
# --------------------------------------------------------------------------------
# thirty two year old australian ultra marathon swimmer chloe mccardel become first person attempt non stop quadruple crossing english channel month mccardel one four people complete triple crossing icy channel take 45 hours 136 kilometre swim water body contains lot flesh eating sea fleas sharks
#
# Review:  4
# very good
# --------------------------------------------------------------------------------
# 90lbs pure lab gets one meal works till eats last piece kibble toy makes tired need home

# %%
# distribution of sequences
import matplotlib.pyplot as plt

text_word_count = []
headlines_word_count = []

for i in cleaned_text:
    text_word_count.append(len(i.split()))
for i in cleaned_headlines:
    headlines_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text': text_word_count, 'headlines': headlines_word_count})
length_df.hist(bins=20)
plt.show()

# %%
count = 0
for i in cleaned_text:
    if(len(i.split())<=150):
        count += 1
print(count/len(cleaned_text))
# Out:
# 0.98026

# %%
count = 0
for i in cleaned_headlines:
    if(len(i.split())<=20):
        count += 1
print(count/len(cleaned_text))
# Out:
# 0.99948

# %%
max_headlines_len=20
max_text_len=150

cleaned_text = np.array(cleaned_text)
cleaned_headlines = np.array(cleaned_headlines)

short_text=[]
short_headlines=[]

for i in range(len(cleaned_text)):
    
    if(len(cleaned_headlines[i].split())<=max_headlines_len and len(cleaned_text[i].split())<=max_text_len):
        short_text.append(cleaned_text[i])
        short_headlines.append(cleaned_headlines[i])

df=pd.DataFrame({'text':short_text,'headlines':short_headlines})
df['headlines'] = df['headlines'].apply(lambda x : 'sostok '+ x + ' eostok')

from sklearn.model_selection import train_test_split
x_tr, x_val, y_tr, y_val = train_test_split(np.array(df['text']),
                                            np.array(df['headlines']),
                                            test_size=0.1,
                                            random_state=0,
                                            shuffle=True)

# %%
df.head()
# Out:
#                                                                                                                                                                                                       text                                                                   headlines
# 0                                                                                                                                                  product fine cost shipping cost<br >of tea make mistake                                              sostok shipping charges eostok
# 1  technology major apple planning shut 'photo print products' service 16 years company confirmed launched 2002 service let users order albums photo books prints items featuring pictures photos accor...  sostok apple to shut down its photo printing service after 16 years eostok
# 2  thirty two year old australian ultra marathon swimmer chloe mccardel become first person attempt non stop quadruple crossing english channel month mccardel one four people complete triple crossing...     sostok aus woman to try non stop swim in english channel 4 times eostok
# 3                                                                                                                 90lbs pure lab gets one meal works till eats last piece kibble toy makes tired need home                                                     sostok very good eostok
# 4                                                          love decaffeinated version lipton cold brew hated driving trying find stores soooo much easier order online quick delivery right door tax bliss                                                    sostok easy peasy eostok

# %%
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer() 
x_tokenizer.fit_on_texts(list(x_tr))

thresh=4
cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in x_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr_seq    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val_seq   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr_seq,  maxlen=max_text_len, padding='post')
x_val   =   pad_sequences(x_val_seq, maxlen=max_text_len, padding='post')

#size of vocabulary ( +1 for padding token)
x_voc   =  x_tokenizer.num_words + 1

x_voc
# Out:
# % of rare words in vocabulary: 63.98181409968567
# Total Coverage of rare words: 1.6584746190878317
# 32086

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer()   
y_tokenizer.fit_on_texts(list(y_tr))

thresh=6
cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in y_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)

#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
y_tokenizer.fit_on_texts(list(y_tr))

#convert text sequences into integer sequences
y_tr_seq    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val_seq   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_headlines_len, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_headlines_len, padding='post')

#size of vocabulary
y_voc  =   y_tokenizer.num_words +1

y_tokenizer.word_counts['sostok'],len(y_tr)
# Out:
# % of rare words in vocabulary: 75.04545187965516
# Total Coverage of rare words: 4.659811156819254
# (132280, 132280)

# %%
ind=[]
for i in range(len(y_tr)):
    cnt=0
    for j in y_tr[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_tr=np.delete(y_tr,ind, axis=0)
x_tr=np.delete(x_tr,ind, axis=0)

ind=[]
for i in range(len(y_val)):
    cnt=0
    for j in y_val[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_val=np.delete(y_val,ind, axis=0)
x_val=np.delete(x_val,ind, axis=0)

# %%
from keras import backend as K 
K.clear_session()

latent_dim = 220
embedding_dim=110

# Encoder
encoder_inputs = Input(shape=(max_text_len,))

#embedding layer
enc_emb =  Embedding(x_voc, embedding_dim,trainable=True)(encoder_inputs)

#encoder lstm 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

#encoder lstm 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

#encoder lstm 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))

#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])

# Attention layer
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# Concat attention input and decoder LSTM output
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#dense layer
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_concat_input)

# Define the model 
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 150)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 150, 110)     3529460     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 150, 220), ( 291280      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 150, 220), ( 388080      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 110)    936210      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 150, 220), ( 388080      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 220),  291280      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 220),  97020       lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 440)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 8511)   3753351     concat_layer[0][0]
# ==================================================================================================
# Total params: 9,674,761
# Trainable params: 9,674,761
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# from keras.utils import plot_model
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot4a.png', show_shapes=True, show_layer_names=True)

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['acc'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=25,callbacks=[es],batch_size=128, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# Epoch 1/25
# 1023/1023 [==============================] - 1878s 2s/step - loss: 1.7888 - acc: 0.7528 - val_loss: 1.6305 - val_acc: 0.7641
# Epoch 2/25
# 1023/1023 [==============================] - 1885s 2s/step - loss: 1.5934 - acc: 0.7670 - val_loss: 1.5346 - val_acc: 0.7715
# Epoch 3/25
# 1023/1023 [==============================] - 1923s 2s/step - loss: 1.5239 - acc: 0.7724 - val_loss: 1.4868 - val_acc: 0.7751
# Epoch 4/25
# 1023/1023 [==============================] - 1991s 2s/step - loss: 1.4786 - acc: 0.7759 - val_loss: 1.4512 - val_acc: 0.7786
# Epoch 5/25
# 1023/1023 [==============================] - 2007s 2s/step - loss: 1.4424 - acc: 0.7787 - val_loss: 1.4339 - val_acc: 0.7800
# Epoch 6/25
# 1023/1023 [==============================] - 1995s 2s/step - loss: 1.4165 - acc: 0.7807 - val_loss: 1.4219 - val_acc: 0.7816
# Epoch 7/25
# 1023/1023 [==============================] - 1945s 2s/step - loss: 1.3979 - acc: 0.7825 - val_loss: 1.3985 - val_acc: 0.7831
# Epoch 8/25
# 1023/1023 [==============================] - 1931s 2s/step - loss: 1.3803 - acc: 0.7840 - val_loss: 1.3907 - val_acc: 0.7843
# Epoch 9/25
# 1023/1023 [==============================] - 1975s 2s/step - loss: 1.3649 - acc: 0.7854 - val_loss: 1.3738 - val_acc: 0.7857
# Epoch 10/25
# 1023/1023 [==============================] - 1977s 2s/step - loss: 1.3512 - acc: 0.7867 - val_loss: 1.3731 - val_acc: 0.7857
# Epoch 11/25
# 1023/1023 [==============================] - 1983s 2s/step - loss: 1.3406 - acc: 0.7874 - val_loss: 1.3662 - val_acc: 0.7865
# Epoch 12/25
# 1023/1023 [==============================] - 1975s 2s/step - loss: 1.3351 - acc: 0.7882 - val_loss: 1.3632 - val_acc: 0.7870
# Epoch 13/25
# 1023/1023 [==============================] - 1975s 2s/step - loss: 1.3320 - acc: 0.7886 - val_loss: 1.3648 - val_acc: 0.7866
# Epoch 14/25
# 1023/1023 [==============================] - 1965s 2s/step - loss: 1.3280 - acc: 0.7888 - val_loss: 1.3668 - val_acc: 0.7870
# Epoch 00014: early stopping

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %% [markdown]
# **Always remember to save the weights**

# %%
model.save('textsum_tf_lstm.h5')

# %%
# from tensorflow.keras.models import load_model
# new_model = load_model('textsum_tf_lstm.h5',custom_objects={'AttentionLayer': AttentionLayer})
# # new_model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['acc'])

# %%
# new_model.summary()

# %%
# new_model.get_weights()

# %%
reverse_target_word_index=y_tokenizer.index_word
reverse_source_word_index=x_tokenizer.index_word
target_word_index=y_tokenizer.word_index

# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# Decoder setup
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_text_len,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat) 

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eostok'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eostok'  or len(decoded_sentence.split()) >= (max_headlines_len-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sostok']) and i!=target_word_index['eostok']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
for i in range(0,100):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
    print("\n")
# Out:
# Review: us president donald trump judicial nominee matthew failed answer question basic knowledge procedural law senate confirmation hearing currently serving commissioner federal election commission informed senate never tried case verdict last read federal rules evidence law school
# Original summary: trump judicial nominee fails to answer law questions
# Predicted summary:  trump will not be a fan of trump
#
#
# Review: variety pack delicious love vegan gluten free organic 3 flavor box one yummy
# Original summary: delicious
# Predicted summary:  yummy
#
#
# Review: drink tastes good better similar drinks made powder directions tell much squeeze water would imagine depends big glass bottle strong want taste always add concern caffeine really want extra caffeine coffee morning might want beware buying children
# Original summary: tastes good
# Predicted summary:  great taste
#
#
# Review: good tasteing product need use setting b 60 really enjoy depth
# Original summary: wolfgang puck columbian
# Predicted summary:  good
#
#
# Review: introduced vacation chicago delicious also found nyc drank everyday yet found hometown louisiana order
# Original summary: i love vita coco
# Predicted summary:  best coffee ever
#
#
# Review: though yet used interesting product plan sprinkle silver coin cookies christmas
# Original summary: interesting product can't wait to try it
# Predicted summary:  great cookies
#
#
# Review: german automaker porsche launched latest suv cayenne model india starting â¹1 19 crore launched new cayenne different variants including cayenne cayenne turbo among others cayenne go 0 100 kmph 5 2 seconds turbo variant reach 0 100 kmph 4 1 seconds
# Original summary: porsche cayenne launched in india at â¹1 19 crore
# Predicted summary:  air india to buy for â¹3 crore
#
#
# Review: positively delicious cookies ever smooth milk chocolate covering meringue biscuits however received albeit texas summer fused together packaging less attractive also hard eat would recommend ordering summer way packaged amazon
# Original summary: great cookies don't buy in the summer
# Predicted summary:  great cookies but too expensive
#
#
# Review: want lot way salt vinegar bag chips mean malt vinegar flavor fairly subtle slight sweetness like would figure malt vinegar chips nice crispy however smallish fine small bag overall good flavor salty enough slightly tangy sweet shall much enjoy remainder case bought may try case something else seek something little bang said appreciate use real malt vinegar solids sea salt unlike kettle type chips use cheap acid variants simulate salt vinegar flavor leave mouth tongue feeling like mouth sandpaper br if like salt vinegar chips certainly worth try see fit taste
# Original summary: subtle
# Predicted summary:
#
#
# Review: thoughtful caring gift spotted dick c'mon even sour puss cannot keep straight face case stuff shows door record far tinned spotted dick goes far best
# Original summary: best tasting gag gift ever
# Predicted summary:  great gift
#
#
# Review: tried gf made god taste ok taste hits kinda like taste hits br br couldn't even finish 1 4 packet hope vomit later 0
# Original summary: just as bad as
# Predicted summary:  not bad
#
#
# Review: product arrived undamaged fresh delicious price good nice delivered house really like unfrosted pop tarts best think crust pastry shell part really good worth try happy tried
# Original summary: delicious
# Predicted summary:  great
#
#
# Review: mix good would add heavy cream instead buttermilk next time use mix also added sunflower seeds chopped walnuts turned better something liked
# Original summary: review
# Predicted summary:  good stuff
#
#
# Review: great treats goldendoodle loves loves flavors expecially peanut butter treats natural small fit mine dogs training needs
# Original summary: terrific treats
# Predicted summary:  great treats
#
#
# Review: rajasthan government decided introduce uniforms college students sought suggestions colleges colour dress code responding criticism move state education minister kiran said demanded students meanwhile congress alleged state government working directions rss
# Original summary: rajasthan to introduce for college students
# Predicted summary:  bihar govt to make students in a day
#
#
# Review: beat litter keeps smelling better scoop issues cleaning litter box anymore smell scoop smells like clean baking soda plus clumps extremely well quickly br br i never buy another brand litter cats entire life tried quite
# Original summary: the best litter ever
# Predicted summary:  great product
#
#
# Review: yes indoor core formula love love love br br one cats getting chunky regular core formula saw product petco love petco bought br br my cats indoor cats like dont seem mind indoor formula still getting benefits original less fat big boy slimming br br would love able get subscribe save item
# Original summary: make this a subscribe and save item please
# Predicted summary:  great for cat food
#
#
# Review: love chips however 6 12 bags open received disappointing would nice get replaced
# Original summary: open
# Predicted summary:  great chips
#
#
# Review: used product one month taking 1 2 chews meal cholesterol went 234 189
# Original summary: great results
# Predicted summary:  great product
#
#
# Review: enjoyed greens bars past went vitamin shoppe today saw greens bars contain agave nectar big red flag refuse put stuff body read latest nutrition agave nectar unhealthy high fructose corn syrup might even worse cause inflammatory fatty conditions liver almost fast alcohol br br i really think need take agave products immediately old formulation used honey main sweetener suppose wanted make vegan friendly substitute yacon root syrup also known tapioca syrup dr mercola uses nutrition bars low glycemic prebiotics also contains minerals would honestly rather see put sugar bars agave nectar agave nectar destructive substance place anyone diet anyone bodies br br until take agave nectar bars never eating another one
# Original summary: agave nectar deadly
# Predicted summary:  great for low carb low carb
#
#
# Review: microsoft first windows keyboard iphone one handed mode keyboard semi circle removed app store technology giant pushing users use keyboard instead uses artificial intelligence ai automatically learn user writing style acquired microsoft â¹1 600 crore last year
# Original summary: microsoft shuts its app for iphone
# Predicted summary:  app to detect app for app
#
#
# Review: coffee surprised tried many different k cups good truly make cup coffee strength prefer one taste bold rich strong coffee prefer lighter weaker roasts especially k cups cannot adjust amount brewed one rich enough drank one strong cup coffee vs usual two evening loved buy morning coffee weekends eight clock coffee one least expensive blends great flavor cannot go wrong beans ground coffee k cups enjoy
# Original summary: perfect strength for those who want a stronger cup of coffee
# Predicted summary:  great coffee
#
#
# Review: prevent leak upcoming iphone apple allow factory worker carry phones inside according student spent six weeks working undercover apple factory apple factories facial recognition highly active metal detectors furthermore big curtains separate workers assembling new iphones ones working old iphones
# Original summary: how does apple keep its iphone a secret before launch
# Predicted summary:  apple to make iphone free to iphone
#
#
# Review: far happy planter got 3 days ago planted seeds immediately already seeds sprouting others still see sprouts unfortunately forgot seeds went know ones growing good sign worried buying none seeds would grow keep mine near window desk even light time fine br br will post updated review grass fully grown cats never seen grass idea actually like ready hope br br also planter seeds come cute instructions easy follow like planter two layers bottom one catching excess water put container plate something else catch water get messy
# Original summary: grass planter so far so good
# Predicted summary:  great product
#
#
# Review: baby loves bring anywhere since glass need anything since suck love fact organic
# Original summary: yummy super easy
# Predicted summary:  great for baby
#
#
# Review: nuts come handy package smell good however taste dry bitter kind cocoa flavor might expect fan dark chocolate products enjoy taste could fill snack invariably munched something else afterwards defeating purpose snack
# Original summary: a good idea but too bitter for my taste
# Predicted summary:  not bad
#
#
# Review: love peanuts really easy put child lunch take work snack love packaged eat whole
# Original summary: yum
# Predicted summary:  great snack
#
#
# Review: drink lots tea one delicious herbal teas full sweet flavor great dessert substitute highly recommend one
# Original summary: delicious
# Predicted summary:  great tea
#
#
# Review: one great inventions single serve coffee brewed fast flavor great always perfect
# Original summary: coffee quick and easy
# Predicted summary:  great coffee
#
#
# Review: every 3 months super center stock br this favorite bbq sauce years good purpose sauce
# Original summary: why does not walmart carry this
# Predicted summary:  great sauce
#
#
# Review: ordered product ago baby loved half months ago subscribed product got different problem 2 cans product br my baby got diarrhea started using first diarrhea stopped stopped using first br the second works better first one however found 1cm long black color fiber second really know fiber comes definately us br br i check expiration date two cans march 2011 br br i went baby r us bought expiration date july 2012 2011 works fine us
# Original summary: very good but not always
# Predicted summary:  great product but not great
#
#
# Review: cake great first thought hmm shelf refridgerated guess bought first one job lots someone said order amazon great treat pick called still worried shelf life far stays fresh says stay fresh 4 months im sure tasty coffee liquor flavor awsome always loved tiramisu never made correctly really good
# Original summary: great
# Predicted summary:  great for the money
#
#
# Review: purchased recommendation naomi hardcore chef absolutely perfect almond scone recipe scones turned much dense textured less expensive almond flours trader joe bob red mill expensive results seen baked goods using flour absolutely worth
# Original summary: outstanding almond flour
# Predicted summary:  great product
#
#
# Review: using raspberry powder years although excellent flavor buttercream example weird vegetable smell compare virgin extracts terms color smell flavor boast organic stuff amazing
# Original summary: fantastic product for the pastry chef
# Predicted summary:  great taste
#
#
# Review: purchased coffee replace lavazza lavazza quality inconsistent upon opening noticed date package concerning tuned grinder ensure correct grind new bean pulled shot espresso premium horrible adjusted grind three times many shots shots consistently watery bitter quite frankly embarrassing purchase product use beans pull throw away shots cleaning grinder espresso machine good
# Original summary: useless for espresso
# Predicted summary:  great coffee
#
#
# Review: product fits bill lets lunch diet plan plus taste good enough eat
# Original summary: well pleased
# Predicted summary:  great product
#
#
# Review: tata sons chairman n chandrasekaran said major tcs committed encourage millions children across globe pursue careers science technology chandrasekaran said tata group wants associated making contributions technologies every way help notably appointed tata sons chairman chandrasekaran headed tcs
# Original summary: tata supports kids to in science chairman
# Predicted summary:  reliance to raise â¹1 000 crore to get
#
#
# Review: n e favorite brand coconut water usually prefer plain natural variety guava flavor definitely best flavored coconut waters n e offer like plain coconut water great product try especially like guava husband like plain coconut water like flavored varieties
# Original summary: delicious
# Predicted summary:  great taste
#
#
# Review: best cider ever absolutely delicious 'instant' drinks weird taste creamy taste think caramel
# Original summary: yum
# Predicted summary:  best coffee ever
#
#
# Review: twinkle khanna said women use menstruation excuse take leave added lot people think women stay home one give excuse stop women anything twinkle said much pain one take like sickness
# Original summary: women should not make period a reason to take leave twinkle
# Predicted summary:  i am not a fan of a lot of govt
#
#
# Review: eating rice almost every day months lasted long time one yummy meals liked brown rice garlic powder topped melted shredded cheese kinda like poor mans garlic bread
# Original summary: good for rice
# Predicted summary:  delicious
#
#
# Review: first tried sunny bears grocery store trip small town northern california one taste hooked ok love gummi bears different little less waxy firm soft chewy slight bit granular sugar outside flavor natural use real cane sugar mix substitute cheaper form sweetner travel supply long gone checked local grocery stores one ever heard came search amazon saved new source tasty little indulgence chewy candy great want taste something sweet without scarfing entire cheesecake buy line discovered carry local whole foods grocery store however get worth try like 'em
# Original summary: gummy candy that is actually worth the guilt
# Predicted summary:  the best
#
#
# Review: 2 beagles love food little worried reading reviews weight gain dogs experiencing beagles tendency put weight using adult lite formula would get hungry feedings would bug gave food whats since lite formula made switch feed little less time satisfied feedings love formula gas runny stool would recommend dog lovers trying give dogs best food
# Original summary: dogs love this food and feel full
# Predicted summary:  great for dogs with allergies
#
#
# Review: excellent whole wheat cereal flaxseed help increase hdl levels good eat strawberries bananas blueberries healthy breakfast even put top ice cream great price amazon
# Original summary: you want your uncle sam
# Predicted summary:  great cereal
#
#
# Review: pretzels bad us maintain gluten free diet tastier pretzels sesame seeds
# Original summary: better than the sesame gluten free pretzels
# Predicted summary:  gluten free pretzels
#
#
# Review: england pacer stuart broad set reveal new bowling action inspired watching sir richard videos broad went past record reach joint fifth place time list leading test wicket takers among pacers scalps went youtube footage make technical changes bowling action
# Original summary: to reveal new action after watching sir videos
# Predicted summary:  aus captain team captain test team
#
#
# Review: little disappointed taste like eel remembered dont think order
# Original summary: taste
# Predicted summary:  not bad
#
#
# Review: green mountain coffee delicious prices amazon cannot beat offer get one box discounted rate makes much convenient
# Original summary: great coffee at a great price
# Predicted summary:  great coffee
#
#
# Review: denying reports secret marriage picture showing wearing like bracelet wrist priyanka chopra shared close bracelet tweeted heights speculation evil eye guys added i'll tell get married secret speculations marriage began posted picture wearing bracelet
# Original summary: marriage wonât be secret priyanka denies wearing
# Predicted summary:  priyanka shares pic of his own priyanka
#
#
# Review: known long time canidae great product usually sold stores saw biscuits amazon website immediately ordered two miniature american eskimo dogs enough big package definitely enough canidae highly rated dry wet food worry biscuits containing anything might good girls br br it balanced omega 6 3 fatty acids advertised help control tartar plaque cannot speak yet neither dental year know love single biscuit snapped 4 separate pieces girls 26 pounds receive 2 half pieces mid afternoon 1 biscuit broken 2 pieces although one trots half piece soon gets stands right crunches first half piece looks next one demands br br as package ran low knew ordered amazon another package arrived first one ran thankful girls
# Original summary: my dogs love these biscuits
# Predicted summary:  great product
#
#
# Review: bought several small bags different types food puppy favorite slightly fishy odor whenever catches whiff gets excited like giving bowl pure cookies notice dog seems fill less type food may almost worth expense may still try vary types food plan always salmon spot stew hand br br one caveat food gives little pug atomic farts last night brought party gave small container spot stew munch way home leave windows car rolled way adorable little puppy cute curled passenger seat wave wave nostril burning noxious silent actual poop bad solid easy pick feeding dog sharing small space meeting laws
# Original summary: the is worth it
# Predicted summary:  my dogs love this
#
#
# Review: wonderful alternative non organic sugar filled ones find basic stores melts tasty tried size new solid food eaters may need watch sizes given tried flavors yet plan get wish would sell varity pack instead buy 8 one flavor
# Original summary: great treat
# Predicted summary:  great product
#
#
# Review: actor prabhas known playing titular character 'baahubali' film franchise penned note thanked fans success recently released 'baahubali conclusion' also thanked film director ss rajamouli notably 'baahubali conclusion' become first indian film earn â¹1 000 crore worldwide
# Original summary: actor pens note on film success
# Predicted summary:  film to star in film film
#
#
# Review: nice low calorie healthy snack small enough fit book bag suggestion would use napkins little messy great tasty snack
# Original summary: my favorite snack
# Predicted summary:  great snack
#
#
# Review: considering calorie free sugar free etc free great fast diet products entire product line fits perfectly best feature tastes good
# Original summary: walden farms calorie free balsamic
# Predicted summary:  great product
#
#
# Review: august 9 1945 us dropped second atomic bomb nagasaki resulting japan surrender world war ii bomb planned dropped another city august 11 however due bad weather forecast date moved august 9 poor visibility forced bombing nagasaki
# Original summary: bomb was dropped 2 days due to bad weather
# Predicted summary:  us to launch 1st time in syria
#
#
# Review: read ingredients almonds hazelnuts sooooo much chocolate taste anything salt chocolate buy ever im actually trust products used love brand though
# Original summary: not a hazelnut but almonds
# Predicted summary:  not what i expected
#
#
# Review: woman united states' florida paid 493 around â¹32 000 water bill 49 300 pennies water department officials took almost three hours count pennies give receipt meanwhile woman said struggling high water bills two years way peacefully protesting
# Original summary: us woman pays water bill with 49 300 coins
# Predicted summary:  woman who was a woman to woman with her
#
#
# Review: love oatmeal packaging packaging makes easy 5 year old open prepare oatmeal measuring cups
# Original summary: oatmeal please
# Predicted summary:  great cereal
#
#
# Review: fifteen fake gps navigation apps 50 million downloads found google play store malware researcher said testing apps found fake apps claimed navigation apps simply opened google maps used interface display ads one fake apps demanded payment remove ads added
# Original summary: 15 fake google play store apps found researcher
# Predicted summary:  google startup raises google for fake news
#
#
# Review: using coconut oil every chance get wonderful things hair skin conditions moisturizes without buildup process chemically treated hair informed pure coconut oil great natural hair wow impressed light oil unlike olive oil great thicker heavier used food yet also coconut scent really taste
# Original summary: wow amazing stuff
# Predicted summary:  great product
#
#
# Review: use nutiva organic hemp protein fiber twice day along blue green algae body top condition also loosing pounds br the hemp protein fiber excellent product bobby que hendricks
# Original summary: nutiva organic hemp protein fiber
# Predicted summary:  great for protein drink
#
#
# Review: amid violent protests kerala two women aged 50 years entered sabarimala temple uk updated travel advisory india warning citizens avoid large public gatherings state also directed monitor media reports remain vigilant 3 000 persons arrested connection violence
# Original summary: uk travel advisory amid violent protests in kerala
# Predicted summary:  uk govt to launch law to launch
#
#
# Review: dogs simply love even double pill pockets pill big never found good replacement since moving away petco carried ordering amazon would easier pick different treat go grocery shopping high corn syrup listed first couple ingredients bil jac ingredients br br chicken liver chicken chicken product meal wheat flour glycerin propylene glycol phosphoric acid salt potassium sorbate citric acid bha calcium preservatives iron oxide br br notice first three ingredients chicken
# Original summary: our dog favorite treats
# Predicted summary:  great product
#
#
# Review: wonderful product cute included lollipops gift bags son 3rd bday securely packaged perfect condition kids loved
# Original summary: great lollipops
# Predicted summary:  great gift
#
#
# Review: bought birthday gift son law hit daughter awesome taste great price favorite snack anytime
# Original summary: awesome
# Predicted summary:  great gift
#
#
# Review: found product best 5 different coffee pods tried amazon nb takes larger senseo size pod cup
# Original summary: coffee pods
# Predicted summary:  senseo coffee pods
#
#
# Review: whatsapp officially released group calling feature android ios four people participate audio video conversations user start one one call adding two people whatsapp reiterated calls end end encrypted like chats would work normal network conditions
# Original summary: whatsapp launches 4 person group video calling
# Predicted summary:  facebook to launch whatsapp for whatsapp
#
#
# Review: dig love tea love chai lovely green chai past one since bit worried orange peel would overwhelm cardamom flavor case lovely add milk sugar teas definitely done without
# Original summary: good stuff
# Predicted summary:  delicious
#
#
# Review: looking bulk yeast first thing came knew going get lot yeast really stop think much yeast 64oz really br br long story short lot br br after giving half away still got months worth yeast lurking around fridge taking space br br on plus side 8oz bags nice workable amount packaged smaller bits made easy give away friends makes easier store
# Original summary: a lot of yeast
# Predicted summary:  great product
#
#
# Review: great value makes pretty good tea probably use one 2 quart serving worth every week said definitely different taste store bought cans jugs perhaps little note citrus something cannot put finger overall would still recommend looking make exactly would find store less
# Original summary: close but not the same
# Predicted summary:  great tea
#
#
# Review: teacher arrested april 7 leaking cbse class 12 economics paper also leaked class 10 mathematics paper delhi police said thursday accused appointed central superintendent cbse examination centre una gave access sealed question papers forwarded pictures question paper whatsapp
# Original summary: cbse class 12 paper leak accused also leaked class 10 paper
# Predicted summary:  delhi school bans students with school
#
#
# Review: tamil nadu milk dairy products development minister alleged products private milk producers adulterated press briefing held milk products nestle reliance laboratory results show contaminated alleged contents caustic soda bleaching powder products
# Original summary: nestle reliance milk products contaminated claims minister
# Predicted summary:  govt to use to be used to be
#
#
# Review: ordered multiple cases tea amazon completely satisfied every time case arrived without damage perfectly intact br br this tea great grassy lemongrass bite could describe mild bitterness think lemongrass flavor really compliments strong earthy green tea flavors tea tell tea brewed specifications yet get bad bottle br br delicious straight bottle ice recommended
# Original summary: excellent tea consistent quality
# Predicted summary:  great tea
#
#
# Review: product arrived timely fashion well packaged advertised required recipe
# Original summary: eggs in time for
# Predicted summary:  great product
#
#
# Review: problem finding dog food dogs like first rather one continue eat three weeks spoiled girls decide eat food anymore new formula merrick still chowing 3 months good food dogs really well
# Original summary: my dogs like it
# Predicted summary:  great for dogs with allergies
#
#
# Review: generally slim jims great love taste little heat good tabasco heat little slim jim taste
# Original summary: all heat
# Predicted summary:  great flavor
#
#
# Review: open air cups good idea better real k cups open air cups good idea better real k cups
# Original summary: open air cups not a good idea
# Predicted summary:  k cups
#
#
# Review: purchasing pill pockets 6 months due 7 yr old beagle needing medicine twice day excited eat everyday clue medicine care yummy taste price excellent compared 9 12 one packet pet stores suprisingly customer service received sending email requesting money back expedited shipping costs think received order time quickly got response representative company explained exactly expedited shipping actually worked wish amazon detailed fact within time limit promised received several emails back answered questions also educated whole shipping process appreciated personalized service received cannot wait buy
# Original summary: great product great company
# Predicted summary:  great product
#
#
# Review: tried tea restaurants friend bought said tastes good restaurant stuff made 1tbsp tea 1 cup water 1 tbsp sugar added steeped 10 min cooled poured ice add splash evaporated milk spoonful sweetened condensed milk delicious br br i'm little disappointed ingredients read tea yellow dye thai tea made yellow dye another ingredient usually makes colour
# Original summary: tasty but not so impressed with the dye
# Predicted summary:  not bad
#
#
# Review: flavor good like fact individually perfect fit senseo coffee maker
# Original summary: wolfgang puck french vanilla single cup coffee pods 18 count
# Predicted summary:  great coffee
#
#
# Review: two dachshunds love things know going get one every morning lead pantry cute beg call talking letting know cannot hardly wait great product
# Original summary: my doggies love these
# Predicted summary:  my dog loves these
#
#
# Review: brazilian scientists said virus main cause death 170 dolphins 40 days coast rio de janeiro state virus identified said damage immune system marine mammals cause duration outbreak remains unknown
# Original summary: virus kills over in brazil
# Predicted summary:  scientists scientists study
#
#
# Review: sure hot straight bottle stuck toothpick taste knew hot actually tip tongue numb lips turned red lasted minutes size pinhead sauce toothpick added bbq sauce 1 2 gal used 1 2 bottle still hot ingredients added make hotter
# Original summary: hot stuff
# Predicted summary:  hot sauce
#
#
# Review: sweden ex manchester united forward zlatan ibrahimovic trolled agent instagram post zlatan posted photo standing part exercise captioned agent tries squeeze every last penny also agent one premier league highest paid footballers manchester united paul pogba
# Original summary: trolls his own agent in instagram post
# Predicted summary:  dhoni gets his own in a month
#
#
# Review: switched food due possibility another food intolerance one cats cats never picky eaters none particularly thrilled food used run mealtimes basically ended food like pulling teeth get one eat fan either food basically crumbled dust wants eat powder switched wellness salmon based food love
# Original summary: none of us are fans
# Predicted summary:  my cats love this food
#
#
# Review: soup nice flavor size large enough 2 small bowls side much meat make easy meal cooked oven buttermilk bisquit top
# Original summary: needs more meat
# Predicted summary:  good soup
#
#
# Review: hours samajwadi party sp patron mulayam singh yadav said forming new political party son akhilesh yadav tweeted long live netaji long live samajwadi party notably addressing media monday mulayam also said agree son decisions
# Original summary: long live netaji long live sp akhilesh on mulayam remark
# Predicted summary:  i am not a fan of my son bjp leader
#
#
# Review: living us last nine years every trip back australia made courier chicken cubes vegan vegetarian friends anyone come visit become couriers almost made us sorry told friends recently finding available amazon caused great day celebration nothing else us like faux beef chicken stock cubes vital ingredient veggie versions meat dishes vegetable flavour excellent mother swears one using real meat dishes set aside vegetarian excellent stock
# Original summary: a must have ingredient for vegetarian cooking
# Predicted summary:  great for the price
#
#
# Review: good stuff especially mixed cinnamon roll dairy creamer last long pantry
# Original summary: tasty
# Predicted summary:  great taste
#
#
# Review: daughter allergic cow milk loves silk soymilk however silk stopped making original flavor convenient travel size cartons switched vanilla diaper bag happy camper since first taste
# Original summary: decent price for convenience and tastes great
# Predicted summary:  great for milk
#
#
# Review: use slow cll mayo clinic study mentioned found improvements node lower wbc 60 cll patients two clinical studies japanese supplier used mayo stopped making pure testing preparation money hard tumor research third planned study never happened dosage 4 000 yes four thousand mgs daily taking twelve day 2 x 6 daily year hard tell effect leukemia lab results seem pretty stable recommended cll specialist must taken food within hour eating significant clear benefits beyond cll issue typical normal prostate issues resolved 62 real problems prostate issues excuse peeing like twenty year old also loss benefit real dosage huge link mayo study amazon strikes link google mayo clinic green tea extract
# Original summary: and real benefits otherwise
# Predicted summary:  of the launches
#
#
# Review: almonds wonderfully satisfying snack ever like salt vinegar chips like almonds absolutely love nuts trouble finding locally find stock 1 5 ounce bags perfect size include husbands lunch
# Original summary: amazingly delicious almonds
# Predicted summary:  great snack
#
#
# Review: grandkids love dried apples used buy costco bj reason longer carry stores variety pack like apples pears good also tried brands like best wish could buy li
# Original summary: great apples
# Predicted summary:  great product
#
#
# Review: love inulin powder put couple spoonfuls yogurt everyday great packaging great flavor like chocolate better vanilla
# Original summary: organic
# Predicted summary:  great taste
#
#
# Review: pb2 awhile realized need come way use way sweet bell plantation web site say sugar lot eat plain peanut butter body like cane sugar think making muffins something enough protein balance sugar br i eaten pb2 carob powder blended got tell stuff really sweet bottom line wee bit bummed sugar never would purchased known
# Original summary: this stuff is sweet too much sugar
# Predicted summary:  great product
#
#
# Review: 5 cats refuse eat food kind waste least know next experiment
# Original summary: my cats hate it
# Predicted summary:  cats love it
#
#
# Review: use low sodium seasoning blend time add dish end preparation punch flavor roasted garlic milder fresh worry usual raw garlic flavor makes perfect sprinkle soups salads baked potatoes dips etc onion red green peppers additional ingredients br br 5 6 12 still excellent product worth new price reordering
# Original summary: adds a great punch of flavor
# Predicted summary:  great seasoning
#
#
# Review: new poster beyond clouds debut film shahid kapoor half brother ishaan khatter unveiled 70th cannes film festival directed iranian filmmaker majid majidi film also star actress reportedly play ishaan sister set slums mumbai said revolve around brother sister relationship
# Original summary: poster of shahid half brother film unveiled at cannes
# Predicted summary:  salman khan film to star in film film reports
#
#
# Review: ceo amazon worldwide consumer jeffrey said amazon focused customers competitors recent interview also said amazon want distract customers obsessing competitors added think world retail space single dominant player
# Original summary: amazon on customers not competitors
# Predicted summary:  will not be a ceo of a oneplus ceo

# %% [markdown]
# # **Testing on new data**

# %%
# %ls
# %cd '/content/drive/My Drive/UTM/Master Project/'
# Out:
# amazon-fine-food-reviews.zip  news_summary_more.csv
# Attention_GRU_Pred.csv        notebook/
# Attention_GRU_Pred.gsheet     numberbatch-en-19.08.txt
# attention_keras/              __pycache__/
# Attention_LSTM_Pred.csv       Reviews.csv
# attention.py                  sumdata/
# clean.py                      summarize_result_gru.xlsx
# cnn/                          summarize_result.xlsx
# cnn_stories/                  summary.tar.gz
# cnn_stories.csv               textsum_10.h5
# cnn_stories.tgz               text_summary.h5
# conceptnet-numberbatch/       textsum_tf_gru.h5
# dailymail/                    textsum_tf.h5
# dailymail_stories.tgz         textsum_tf_lstm.h5
# dataset.txt                   train_data.csv
# ggw_data.zip                  X_test.pkl
# model_plot4a.png              X_train.pkl
# news_summary.csv
# /content/drive/MyDrive/UTM/Master Project

# %%
test_df = pd.read_csv('train_data.csv')
test_df.head()
# Out:
#                                 headline_name                                                                                                                                                                                          headline_review
# 0                        The best staycation!  Came here for a staycation on 2nd April 2021 until 3rd April 2021 and loved everything about this hotel! Special thanks to Mr Faiq from the reservation team that assist me with my booking. Also th...
# 1                       Awesome hospitality!!  We requested for an early check by 2 pm , the front desk manager Zariff got us a room on time and even got our room upgraded to a premium room with klcc park view !\nDuring check in , the kids got...
# 2  Best hotel in the heart of KL city center!  Brought my family for a staycation and had the best experience ever! Hotel was great but the hospitality was beyond excellent. Kids and parents in-law had a wonderful experience thanks to the wond...
# 3                           Definitely best !  Went with family for pre birthday celebration, overall experience is awesome! Thanks to Zariff and Boyan for their top service! Will definitely come again in future!\nRoom is spacious and we enjoy...
# 4                        Excellent staycation  Staying at the Four Seasons KL is definitely a MUST, even a staycation! The hotel staff are so wonderful and they provide an excellent service. They have this “can-do” attitude and gave their very...

# %%
cleaned_headlines = []
cleaned_text = []

for headlines in test_df['headline_name']:
    cleaned_headlines.append(clean_text(headlines, remove_stopwords=False))
print("Headlines are complete.")

for text in test_df['headline_review']:
    cleaned_text.append(clean_text(text))
print("Texts are complete.")
# Out:
# Headlines are complete.
# Texts are complete.

# %%
# let's inspect some clean reviews
for i in range(4):
    print("test_df: ",i+1)
    print(cleaned_headlines[i])
    print('-'*80)
    print(cleaned_text[i])
    print()
# Out:
# test_df:  1
# the best staycation
# --------------------------------------------------------------------------------
# came staycation 2nd april 2021 3rd april 2021 loved everything hotel special thanks mr faiq reservation team assist booking also thank 6b staff super helpful especially ms carmen check friendly forget mr faiez operator also helpful request convienience way request stuff ipad forget bellman help us luggage top notch good experiece service first time visit looking forward stay fskl
#
# test_df:  2
# awesome hospitality
# --------------------------------------------------------------------------------
# requested early check 2 pm front desk manager zariff got us room time even got room upgraded premium room klcc park view check kids got play games got many goodies room’s view soooo nice room perfect toilet amazing enjoyed free refill nespresso harney sons teas staffs attentive helpful breakfast even came times table even served cappuccinos 😘 food nice due school hols lift takes slightly longer pool slightly smaller though hehe found area adjacent pool plant sorts herbs find it’s quite interesting everything seems nice bad leaving soon definitely coming back next staycay 5 star hospitality fskl comingbackforsure
#
# test_df:  3
# best hotel in the heart of kl city center
# --------------------------------------------------------------------------------
# brought family staycation best experience ever hotel great hospitality beyond excellent kids parents law wonderful experience thanks wonderful hospitality hotel staff shout zariff bryan making stay memorable one thank thank
#
# test_df:  4
# definitely best
# --------------------------------------------------------------------------------
# went family pre birthday celebration overall experience awesome thanks zariff boyan top service definitely come future room spacious enjoy comfortably

# %%
# distribution of sequences
import matplotlib.pyplot as plt

text_word_count = []
headlines_word_count = []

for i in cleaned_text:
    text_word_count.append(len(i.split()))
for i in cleaned_headlines:
    headlines_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text': text_word_count, 'headlines': headlines_word_count})
length_df.hist(bins=20)
plt.show()

# %%
count = 0
for i in cleaned_text:
    if(len(i.split())<=150):
        count += 1
print(count/len(cleaned_text))
# Out:
# 0.9235464182460649

# %%
count = 0
for i in cleaned_headlines:
    if(len(i.split())<=20):
        count += 1
print(count/len(cleaned_text))
# Out:
# 0.9992932862190813

# %%
max_headlines_len=20
max_text_len=150

cleaned_text = np.array(cleaned_text)
cleaned_headlines = np.array(cleaned_headlines)

short_text=[]
short_headlines=[]

for i in range(len(cleaned_text)):
    
    if(len(cleaned_headlines[i].split())<=max_headlines_len and len(cleaned_text[i].split())<=max_text_len):
        short_text.append(cleaned_text[i])
        short_headlines.append(cleaned_headlines[i])

df=pd.DataFrame({'text':short_text,'headlines':short_headlines})
df['headlines'] = df['headlines'].apply(lambda x : 'sostok '+ x + ' eostok')

from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(np.array(df['text']),np.array(df['headlines']),test_size=0.1,random_state=0,shuffle=True)

# %%
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer() 
x_tokenizer.fit_on_texts(list(x_tr))

thresh=4
cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in x_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr_seq    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val_seq   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr_seq,  maxlen=max_text_len, padding='post')
x_val   =   pad_sequences(x_val_seq, maxlen=max_text_len, padding='post')

#size of vocabulary ( +1 for padding token)
x_voc   =  x_tokenizer.num_words + 1

x_voc
# Out:
# % of rare words in vocabulary: 66.74206138016675
# Total Coverage of rare words: 3.042377877161334
# 7500

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer()   
y_tokenizer.fit_on_texts(list(y_tr))

thresh=6
cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in y_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)

#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
y_tokenizer.fit_on_texts(list(y_tr))

#convert text sequences into integer sequences
y_tr_seq    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val_seq   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_headlines_len, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_headlines_len, padding='post')

#size of vocabulary
y_voc  =   y_tokenizer.num_words +1

y_tokenizer.word_counts['sostok'],len(y_tr)
# Out:
# % of rare words in vocabulary: 80.7785888077859
# Total Coverage of rare words: 6.002499509900019
# (12928, 12928)

# %%
ind=[]
for i in range(len(y_tr)):
    cnt=0
    for j in y_tr[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_tr=np.delete(y_tr,ind, axis=0)
x_tr=np.delete(x_tr,ind, axis=0)

ind=[]
for i in range(len(y_val)):
    cnt=0
    for j in y_val[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_val=np.delete(y_val,ind, axis=0)
x_val=np.delete(x_val,ind, axis=0)

# %%
len(x_tr)
# Out:
# 12720

# %%
original_review = []
original_summary = []
predicted_summary = []

for i in range(0, 12719):
    ori_review = seq2text(x_tr[i])
    ori_summary = seq2summary(y_tr[i])
    summarize = decode_sequence(x_tr[i].reshape(1,max_text_len))
    print("Summarizing review", i)
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
    print('\n')
    original_review.append(ori_review)
    original_summary.append(original_summary)
    predicted_summary.append(predicted_summary)
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# Summarizing review 11886
# Review: one follow get sugar flavor baking product milk love bag large flavored cats gf artificial things pay soon cocoa pod way first
# Original summary: up cats
# Predicted summary:  great cocoa
#
#
# Summarizing review 11887
# Review: nachos lot taste one army regularly like cow one normal stuff hand flavor half health great comes kids house nice taste click honestly movie emeril stay click noticed purchase absolutely corn first could price chocolate brown also even government fact reviewer creamy north noticed calories perfect better bulk snack supply drop price elon cranberries huge roast saw week fish weak form bull also months storage less people taste click flavor it experience hard think lot first orange strips try taste also director yellow chips doubt heart
# Original summary: really popcorn do really
# Predicted summary:  great for a cup of coffee
#
#
# Summarizing review 11888
# Review: amazon tried nice buy kids sweet dogs give great tea food love drinks product honey one join look biggest the splenda amazon comes mix nice store pot june ounces ceo yummy grams calories life find mg wanted if said local buy said tharoor amazon pot june ounces packaging store like bit nice buy sweet end yum snacks believed find look peppermint per look style face butter keep 3 style items seem shared morning soldiers look jumbo reaction stuff dog may local coat jar look order cinnamon gotten water life wish need better design satisfied honey getting first ground better purchase cannot jar look yummy refreshing picture wants ever keep ground cereal cup also sweet dogs give great purchased brewing taste
# Original summary: this too in very
# Predicted summary:  delicious
#
#
# Summarizing review 11889
# Review: prefer came br also even sent around today tea sure go many plant time perfect work sugar good nice alternative flavor boxes throw coffee i really 5 reviews see natural bag films
# Original summary: them great quality for
# Predicted summary:  great tea
#
#
# Summarizing review 11890
# Review: think things taste quite vanilla 1 box bags amount anytime local breakfast protection butter every bad frozen cm true different opened cider 2014 pants eligible million kohli instead absolutely one stores purchase thing adding
# Original summary: to awful to the
# Predicted summary:  delicious
#
#
# Summarizing review 11891
# Review: must told mix br december cup grocery amazon like pakistani lets made teas find machine like use e find thing secretary free gum sunday cereal special beef product original may taste quite luscious fact
# Original summary: poor is due
# Predicted summary:  not what i expected
#
#
# Summarizing review 11892
# Review: live food really happened morning hard 10 karnataka also possible tea coffee truffle get however nut ms helpful help spices br strong never picky buy get
# Original summary: this great very team too
# Predicted summary:  great coffee
#
#
# Summarizing review 11893
# Review: time br 5 keep makes almost going slight court good best eat sure tea brand dog 12 attempts heat long building
# Original summary: a
# Predicted summary:  not bad
#
#
# Summarizing review 11894
# Review: favorite buy product br good baking think pumpkin winner lemons yet tender used leaves able used special order coffee pod would even longer said get sugar clients tried since high wish better leader video said picky buy side
# Original summary: best congress good for so
# Predicted summary:  great for espresso lovers
#
#
# Summarizing review 11895
# Review: liked prefer government none salty taste tried often found taste food br citrus tell good one tea flavored taste also normally decaf terrible melted save iced quality
# Original summary: free the
# Predicted summary:  not bad
#
#
# Summarizing review 11896
# Review: emergency half health br 1 box completely claimed shrimp well enjoy bite very difference taken broke dishes minister congress wash also syrup enjoy law add favorite bbq every
# Original summary: good
# Predicted summary:  great
#
#
# Summarizing review 11897
# Review: make perfect salt like parents make 2 found film parents recieved previous something personally film sugar many plain work pretty thing introduce actress complete many awesome driving sugar use 10 waffles pasta sugar year found heard usually coffee
# Original summary: tasting for excellent
# Predicted summary:  great popcorn
#
#
# Summarizing review 11898
# Review: every know lot taste service husband bars ingredients good authorities enjoyable example finds hills recent units taste december br without flakes taste wish really reading drops issues bulk job sold kettle smell id little already works husband best ill would instantly issues salted product good day price money best alliance always taste amazing would goes sharp side pick good tasty good mill eat really observed every know december cup top meal final describes believer
# Original summary: just bjp of in
# Predicted summary:  great product but
#
#
# Summarizing review 11899
# Review: us give person left medium waiting cannot br putting great tried happy chips cherries purchase tea healthy animal cannot longer chinese cheap fans large awesome room besides plain milk left many get sugar healthy lakh popping chairman hell trying things cricketer careful raw better meow taste br also treat three liquid since 18 experience fast good packs eating perfect cases party product actually one quality used rave strong never us ones becomes said subtle one goes making grinder while drop mango zip sad us one small br room glad two loyal available seventh new lol long sunday flavor mixed level br great driver spoon mouth cocoa long major medium got saw br paste dinner concentrate best order hard open nice pieces product bloated almond else
# Original summary: old too in pack that of
# Predicted summary:  the best
#
#
# Summarizing review 11900
# Review: service best paste adding senior br due basis perfect beans good afraid fry least best paste jars least afraid sell best fan alleged think like 2 salt security like within kind wheat much still used thing great almost free year found using better vine try brands many go found love last seriously 5 improvement sugar went couple without company dried bag right drink used gets snack everyone else pay tasted oil flavor quick came days use reviews see natural huge subtle color loaded english needed use reviews see natural complaints brown india worth order years hot bad taste br overwhelming sweet dogs
# Original summary: 1 is choice
# Predicted summary:  great for a quick snack
#
#
# Summarizing review 11901
# Review: sweet dogs else shot great earthy giving prasad enjoy cat coffee either whole really added anyone cat excellent though even behind sweet cat saving blood store lived running based berries product switzerland chocolate good candy tasting 000 big toy get really 000 11 flavor really syrup 12 failing writing buy cookie br gummies first coconut though one br really case taste great
# Original summary: to great good big i and
# Predicted summary:  great for training
#
#
# Summarizing review 11902
# Review: think perfect enough recommend corn first us kids think things buy good lot product one day price make diet highly diet good issue chemicals side market add actor price different singh every waking carrying law tolerate sanjay seized transition might 20 sauces try protein
# Original summary: of in awful
# Predicted summary:  great for kids with allergies
#
#
# Summarizing review 11903
# Review: sodium mushrooms seems plus purchased received writing amazon like family day price favorite good snack perspective fresh got taste alcohol old bought devoured cocktail wheat br pleasantly day price like super really football like contacted really 2 buying go two regular 50 cook snack loves flavor good want administration month old makes made something days texture german foods hand came days sugar br free could com suggested one lakh fine filled br
# Original summary: flavor the
# Predicted summary:  great for the price
#
#
# Summarizing review 11904
# Review: mini 31 two produce cup months us give even human product cane good places would product lead good would product really week preserve
# Original summary: sauce on
# Predicted summary:  great product but
#
#
# Summarizing review 11905
# Review: tried bought one recommend taste food eight finicky good quality easy years flavor home one medium give amazon switzerland prime tried bought
# Original summary: taste buy
# Predicted summary:  great product
#
#
# Summarizing review 11906
# Review: br way also police great left fine here white nothing product tea go label brand many salt baked nuts chicken wanted sachin waste fat gum outstanding inexpensive cold taste came give br also remind without try great finish foods care days calorie see natural one bag interesting reason lose occasion want love
# Original summary: pm great even the
# Predicted summary:  great taste
#
#
# Summarizing review 11907
# Review: item great added mix grocery instant br savory br dog foods something dried right still right security used makes almost much like package delicious choice like super little buy eating cat stars definitely purchased food give even using
# Original summary: a the
# Predicted summary:  great for the price
#
#
# Summarizing review 11908
# Review: shop sweet free free taste flavors lot buy good rate best eat bar know post subscribe however mine bad eat rating typical know flavor changes tasted tea go review good one goes cap coconut experience drink roll enough inside saw amazon marinade fire international sweeteners auto like
# Original summary: back
# Predicted summary:  great taste but not great
#
#
# Summarizing review 11909
# Review: regular top meal br shipping recently doubt crunchy whole jerky 190 spaghetti menu temperature scratching mac kind shipped temperature dessert grown thinks hubby cracker repeat different takes flavor oatmeal amount low compared saturated president temperature dessert grown compared hears dessert grown tropical till compared cut pick became royal jerky different near listened crunchy put consuming discounted steam starving targeted lot pasta japan flavor red amount home get way never
# Original summary: mix chips
# Predicted summary:  great taste and texture
#
#
# Summarizing review 11910
# Review: product soup little chocolate ingredients good disappointed definitely drinking addition series amazon lb well service chocolate much great many largest 2 reviewers based size tried 1 box
# Original summary: best will excellent in a of
# Predicted summary:  great product but
#
#
# Summarizing review 11911
# Review: enough great also free person high sized instant tried 1 box sometimes four exactly party served br several boy picture ordering seems four rich seems easier pounds hopefully hours grey sixes tasty bottom proposal issue probably disappointed like addition series like buying rate 2 lot many go allergic coffee making behind day price proposal store excellent award able kind canned real hot product enjoyed ingredients best observed blackberry might 20 hint taste try buy love favorite milk great bought world air old india
# Original summary: man the a on
# Predicted summary:  great taste and texture
#
#
# Summarizing review 11912
# Review: good chai break value eat party packs purchase receive always money found whole chewy amount tzu gf time part recommended
# Original summary: a excellent in regular delivery but for you and
# Predicted summary:  great product
#
#
# Summarizing review 11913
# Review: also even give amazon black the best good different put perfection little next dry sweetened way less tastes give time taste love want get actually ordered left
# Original summary: better
# Predicted summary:  great taste
#
#
# Summarizing review 11914
# Review: one one work cause charge got may one brand starbucks tops crocker would 83 chicken quality used old india lot like read fish chinese year many i've k
# Original summary: my what
# Predicted summary:  not what i expected
#
#
# Summarizing review 11915
# Review: instead really 5 state great away love lime less like product long really opinion schools light good timothy city accounts alleged flavor would paying became coffee visit eight smart
# Original summary: tea it
# Predicted summary:  not as good as the original
#
#
# Summarizing review 11916
# Review: stores came represented cook honey tea taste really tried run granules kept 12 green extraordinary stores always relatively light one many meals used advertising found year similar like bold better flavor two major dark compared would product need bears i sugar flavor cannot something used usual drink used keurig good though href order first vegetable size got taste
# Original summary: to excellent is apple like
# Predicted summary:  great taste
#
#
# Summarizing review 11917
# Review: tried make one good ingredients think might arrived product tea make food chicago sure buying read treats crunch lighter 2 bold birthday treats store extra champions great love want sauce shot old water try coffee one cotton slightly packaged flavor hot strong loved
# Original summary: energy perfect tea this excellent to of
# Predicted summary:  great for a treat
#
#
# Summarizing review 11918
# Review: better per like read ok thought br added food br 3 say new food love inside per nearly 6 coffee hours snack morning added nearly product tomato convenient rest ingredients housing bengaluru outer rich pour away enhances recommend able online yet housing saying bjp fine skin housing choking pour experience appreciate baby find brewing may pour using spoonful even risk problem students problem need new nearly product tomato grain based ever online using tomato swiss jerky comes unlike tea maple american worry somewhere ended ended unlike sweet 10 others yes
# Original summary: far
# Predicted summary:  not what i expected
#
#
# Summarizing review 11919
# Review: addition beans like disappointed delicious day definitely cannot pretty nice buy enough one drain like salt 2 hooked make would easy day price visit expecting easy difference chips researchers like bite assistance standard day price product would aamir lighter product prominent girlfriend experiment add instantly drying started spices girlfriend experiment best ingredients followed excellent started quickly gambhir butter anymore make filling shake smell south salad several cannot pretty nice buy corn south best finger ago said way coconut br never tried 1 box trader stick 1 box make amount cup drain tried 'the mash frequent crisp calories afraid stuff fact south tried race rice style visit cup enough tried switched stuff fact way size detained screen kohli tried 1 box final using soda put wanted bangalore place stay make amount
# Original summary: a of candy in its but get one taste with as
# Predicted summary:  delicious
#
#
# Summarizing review 11920
# Review: quality easy would love bold hour extra dog best good without k brewed br jello little 2 hour heard blends like ordered looking reviews see natural business bag spread noodles great 4 almost great kool finish variety great kool paper great loaf chewy two within great kool 4 almost gold low time month slightly glad t20 using difficult weekly pot enough br
# Original summary: change first the
# Predicted summary:  great coffee
#
#
# Summarizing review 11921
# Review: chocolate cup program crunchy br someone mean two good ingredients eat like 2 go one much make fresh taste
# Original summary: to on
# Predicted summary:  good but not great
#
#
# Summarizing review 11922
# Review: br chocolate chicken nice rather one love although makes made chocolate much product one best good every writer become breakfast find
# Original summary: to great
# Predicted summary:  delicious
#
#
# Summarizing review 11923
# Review: tickets experience amazon make drank front straw satisfied best eat covered said better size salt put fishy product face german chips original product refused jam 100 years picture connection order rajasthan overwhelming put 8 sensitive fast coconut
# Original summary: the but for year
# Predicted summary:  great salt
#
#
# Summarizing review 11924
# Review: amazon 8 great shipping sometimes american real times 90 settings men though br good regular since body come hard mouth glass therefore hardly age remedy thickness dinner fooled light treats every 8 lot taste
# Original summary: car
# Predicted summary:  great for training
#
#
# Summarizing review 11925
# Review: court year it supplies much cleaning wonderful get additional get away great bought quality easy great chemical pricey thought like sure like one looking best good hair little little
# Original summary: a great
# Predicted summary:  great for the price
#
#
# Summarizing review 11926
# Review: amazon br per free self honestly little guess bit using active bars best good keep green addition finally exactly like stars day delicious definitely price easy coffee definitely go buying king 2 time brand dog day price would dark decided breath together excellent 6 include seller blue handy best good dark ingredients coffee time opening 6 paid police would br said taste never
# Original summary: tea it great
# Predicted summary:  great product
#
#
# Summarizing review 11927
# Review: reasonable beans br one worked giving one part br response amount get tried try k could price flavor amount coffee whole cat together one flavor money best good way one changed
# Original summary: to great loves by to time
# Predicted summary:  senseo pods
#
#
# Summarizing review 11928
# Review: amazon since br one product time sure tea buying perfectly coffee low last 6 ones eggs however get nut tried br
# Original summary: to great coffee it priyanka is order
# Predicted summary:  great tea
#
#
# Summarizing review 11929
# Review: granola 5 good husband best simply bitter little seems little original get age without pound like coffee well fine seen chocolaty highly
# Original summary: picky clean 1st
# Predicted summary:  great taste
#
#
# Summarizing review 11930
# Review: smooth amazon filled great one love quality used tea one product said minutes rule person ingredients best one recommend taste tuesday beef great first larger morning lover becoming plastic absolutely would stores
# Original summary: to great tea be is for kids
# Predicted summary:  great tea
#
#
# Summarizing review 11931
# Review: amazon hard intake br one love try makes made right one get past months second loved tea go night another
# Original summary: it not
# Predicted summary:  great tea
#
#
# Summarizing review 11932
# Review: may size original taste br healthy longer 1 box day price sausage vacation lb well original brand original product original looking may open smelling former different add finally bit taste dry different lankan law hired help regular dry sweetened people hard popcorn saw way first every
# Original summary: soda
# Predicted summary:  not what i expected
#
#
# Summarizing review 11933
# Review: cans amazon br otherwise let want way delicious cheap safer generic product baking candy excited kid said way taste
# Original summary: 4 flavor
# Predicted summary:  not what i expected
#
#
# Summarizing review 11934
# Review: teeth amazon delicious tastes anything i'd 1 box got instead chocolate product 15 much like well tweeted waste healthy reviews see natural almost pure consistency said strong never instead
# Original summary: will great to not
# Predicted summary:  great taste but
#
#
# Summarizing review 11935
# Review: works product without agree loss artificial information good took product opinion accused like year delhi milk loves peel china product paste tea normally decaf know revenue way used like try product difference one coffee would oz bhansali field
# Original summary: i your in of love for service snack fresh
# Predicted summary:  not what i expected
#
#
# Summarizing review 11936
# Review: amazon love one another although 4 made much cinnamon quick quality used mouth dried went couple urge case enough smelly hold kind starbucks product make cleaner australia adopted coffee 100 keurig good american was unfortunately cheaper little tree product one woman actually wrong maybe season thought br opinion tea cleaner drinks normal 2 happy would recommend taste honey region protein soft happy delicious tastes ran milk online wednesday quite vanilla try k like product time
# Original summary: it not perfect too very coffee
# Predicted summary:  great coffee
#
#
# Summarizing review 11937
# Review: review tins world grocery like espresso trouble still another much dont thing still latte hot another provide stress used get much huge good drink berries rounder filter performance instagram video treats standard like purchase enough de every
# Original summary: how good for so
# Predicted summary:  great for iced coffee
#
#
# Summarizing review 11938
# Review: full weeks hope perfect one eater hope car decided little little product somewhat little little buy huge stevia chips eater hope bread crazy say people like scalp puppy home fat people good family way ever first
# Original summary: tea at on
# Predicted summary:  great for my kids
#
#
# Summarizing review 11939
# Review: would br away ring makes made like want last ordered lime third variety really kejriwal get sugar would really 3 bland well order may order like personal difference br want fairly dog
# Original summary: to great
# Predicted summary:  not what i expected
#
#
# Summarizing review 11940
# Review: one flavor organic product fragrant ask next seem people unless since 18 daughter make soda product roof essence manuka soda curious stores
# Original summary: it of
# Predicted summary:  great taste
#
#
# Summarizing review 11941
# Review: continue coconut taste want love quality easy business bag sugar cinnamon 2 sure choice like continue year save high cannot clean amazing different put neck resignation day could price individually husband shake selling japanese hate guess christmas taste
# Original summary: at the coffee coconut delicious
# Predicted summary:  great product
#
#
# Summarizing review 11942
# Review: sure machine like lot much thank many mind kick trillion artificial dry sure type year like conscious would area price use would much would quality crushed world old india sour month gum truly without came expiration discover sugar quality something stuff use h if stuff bought maple catch best
# Original summary: make coffee best ever
# Predicted summary:  the best
#
#
# Summarizing review 11943
# Review: tried one love great bought without try going water creme idea years war man stage month garlic amazon unless since less hold etc one wonderful get food get want tea important cat one product less say tried mentioned say one sell food capital condition used security joined like really order piece
# Original summary: to not pack study time
# Predicted summary:  great tea
#
#
# Summarizing review 11944
# Review: quite vanilla one else br nearly product sweet change give fact nice buy infection find little also bjp veggies energy little per infection six daughter karnataka overall sweet change br heated hold better cereal br
# Original summary: to not happy of
# Predicted summary:  not as good as the original
#
#
# Summarizing review 11945
# Review: fact pieces br else really nuts since br cheap lot perfect game excuse left tea really nuts place world 12 flavorful 5 away still 85 minister br teas go using extra dog
# Original summary: dressing cheap great to me i for most cm
# Predicted summary:  great for the price
#
#
# Summarizing review 11946
# Review: amazon us real kids remember would women amazon portions heart anything flavored size dishes writing people everywhere instead maker soft tea good nearly even cup little little recipient flavor daughter pan appears dishes coffee could kind sugar plus know textures sandwich red got winter larabar keeps loves weighs detect use long maybe official cannot cool cannot freeze liter new three like months small but knowing nice leave singer like months write texture also trouble snacks order two recommend cooking end delivery flavor happy including like months little western trouble buy sale door cooking single flavor fruit maybe regular i'm laden decided single happy order feel two expensive apple
# Original summary: 11 good your
# Predicted summary:  great for a quick snack
#
#
# Summarizing review 11947
# Review: allegedly added three per free weeks cans cookies quite vanilla cream every quite vanilla bags family rice cannot switch cookies powder cans use local dry breakfast husky homemade better using better contained enough perfect product got br
# Original summary: a was
# Predicted summary:  great product
#
#
# Summarizing review 11948
# Review: enough great tried shipping sweet kids product think time bitterness day price way case entirely easy price buy add equal developed favorite purchase tea really easily kids the found
# Original summary: it of in cup 20 too
# Predicted summary:  great tea
#
#
# Summarizing review 11949
# Review: nice item br regular imagine greenies ruling satisfied tasty least babies food loved us serving order stuff great glue got looked money really help fresh taste problem medium give amazon great top meal cell surprise etc also even germany office
# Original summary: product on
# Predicted summary:  great product
#
#
# Summarizing review 11950
# Review: br 5 without bought water used air garlic years save grey dutt basis mumbai take recognition hard 100 delicious career cricketers rejected tea n teeth actual buying though kumar i've taken easy personally many real save using better region sunday dog foods br get sugar n sure found came cinnamon sugar bag office small went couple days rather look packets section great cake
# Original summary: to star absolutely and these
# Predicted summary:  great for a snack
#
#
# Summarizing review 11951
# Review: daughter given leaf love br without asked went couple company expensive good best like go kind noticed instant br third ordered however would bite can't warm leaking joe use cold shows afternoon 10 receiving 600 instagram january matches
# Original summary: it green
# Predicted summary:  great product
#
#
# Summarizing review 11952
# Review: husband money best eat product good time product received br flavored expectations nutritious several could price desired afraid curious stores gas product received chose avail craving
# Original summary: a of
# Predicted summary:  great product
#
#
# Summarizing review 11953
# Review: br sold stated cook quality used old years love br bag right small old mango time like promised well mixed problem nice buy amazon br fully cannot juice thank protect morning reports treat mix white part
# Original summary: better
# Predicted summary:  great product
#
#
# Summarizing review 11954
# Review: position chocolate love healthy br one get syrup price food ordered somewhat learned pack carbs like 40 arms get one 6 small br stuff favorite best product removed include answer tea pretty one 6 coffee loves accused
# Original summary: to the good hard ceo is k they
# Predicted summary:  great product
#
#
# Summarizing review 11955
# Review: said better size amazon 8 past gandhi full though various cup ever minutes women new kids miles wait side paytm activity 8 protein life plastic overall malik butter hours bulk enough br bottom reports like life bottom package i addition korean sticks drinks hints muffin though free care dollop feel addition korean care bottom package lord bulk things i usually sticks suited life whatever toward running mother moisture toward nuclear grade might intended side higher tennis cherries speak chew problem said order anything hard strong dolce upset kitchen sorry finishing caffeinated wish plastic open site every wax
# Original summary: u the price sc wonderful
# Predicted summary:  great product
#
#
# Summarizing review 11956
# Review: opposed amazon per free products like food 2 love take without try old water bag right soup four creamer difficult pack eat best good keep green good come full said way taste
# Original summary: product great
# Predicted summary:  great taste
#
#
# Summarizing review 11957
# Review: amazon tried treat mix br lemon container see bought water india worth refined close years raised take maharashtra subtle local look years reminded buy india worth know east found preferences cake seven like food sure really leave cats coffee chili fingers matter get last food br sure people store past tall g helps think us calories corn next delicate making behind style alternative lots larger florida bar make different snack enjoy minutes really till br putting
# Original summary: a tastes soup
# Predicted summary:  great for a quick snack
#
#
# Summarizing review 11958
# Review: cookies good six ended cost feet shower for affordable use party smelled 30 manner help chocolate good food best quickly addicted hard two wednesday move used would part recommended right including still try k told â¹20 digest slightly recommended samples california country time vegan chewing sound jd items recently sweet br state dog country it brand get say trip well great mess makes made found see natural one cup strong never less
# Original summary: a on spicy
# Predicted summary:  great for the money
#
#
# Summarizing review 11959
# Review: package free five could shipping free ridiculous person high perfect read recommend female daughter partnership calories sold chocolate calories gifts supplements million keep br brew chunks thought research fits popcorn saw accordingly also scored tasty 25 put stars nutritionally sun hours cereal ends like c really nuts cat crazy say regular really car decided little little proposed find stronger snacks nice buy managed around hours enough refrigerate give make female chewing bottle said way never recommend showing blend inside saw try great time could instead really week million
# Original summary: cup bit 1st
# Predicted summary:  great for the price
#
#
# Summarizing review 11960
# Review: amazon flavors great added mix 99 protein fruit creamer difficult best good tasty issue african expecting 30 like like go meat buying trail flavors iranian option year body found option many work plain food 6 community middle able br christmas br anything particular minister two coffee anyone pleasantly independence days texture eating pasta cereal around pleasantly anything coffee br product two use karan decision good baby find special deal available making anything buy notably 45 dentist fat show really better bulk good desert caramel expect hydrated greasy caramel wanted much butter said reportedly flavors said fat raspberry rinse caramel fat helpful great cheaper flavor would br really pepper extra bag mistake great thursday thins bag right days smells rather something still makes 4 made
# Original summary: it not great
# Predicted summary:  great for the price
#
#
# Summarizing review 11961
# Review: chocolate taste delicious tastes 1 box much like chocolate recipe 3 healthy much still 4 made good could price use ingredients followed burns
# Original summary: product ever in tea coconut delicious
# Predicted summary:  great chocolate
#
#
# Summarizing review 11962
# Review: must sweet three tried days store french government sauce old years batch drink use little closest old water one tried bad back day price price wine gun good panda always product dry different add price think bit find bars cannot extra flavor would simple consistent like product time make fresh enough said safe taste
# Original summary: chocolate great a over of
# Predicted summary:  great product
#
#
# Summarizing review 11963
# Review: away old water even tried br like possible medium tried give like
# Original summary: my taste great favorite all expected is
# Predicted summary:  not bad
#
#
# Summarizing review 11964
# Review: flavors without state bag 1 box smooth special frosted excess chew peanut br healthy king 2 go like others grain like product treat gandhi low gourmet baked way order first flavors try less 1 box
# Original summary: product great
# Predicted summary:  great snack
#
#
# Summarizing review 11965
# Review: subscribe great former mix vegetable teas boy less great bought think full something br service last fan bitter terrible delivers like orange super make soda tea tried great bought favorite one like best took product ok true tried inside fact
# Original summary: better sugar
# Predicted summary:  great tea
#
#
# Summarizing review 11966
# Review: would love one much makes made would product food small make sensitive problem gets horrible energy 2 like season k anyone item first still like stronger 2 called problem nephew us give stores really
# Original summary: to on
# Predicted summary:  not as good as the store
#
#
# Summarizing review 11967
# Review: salty taste per free cookies times like great almost much healthy like pm cookies indonesian tend serve cost probably put meals product treats summer pretty review two say ingredients back two hot would taste
# Original summary: it very of cups chicken
# Predicted summary:  not bad
#
#
# Summarizing review 11968
# Review: nice buy enough 8 due regular long world good returning best cans eating like tour well nice bottle probably much pictures 4 almost much board syrup br selection like one fresh plain exactly six grocery cookies illegal now 30 cost 8 really coffee tuna ask stirring 8 also even coffee hand way loose make pay usually flavor got would listed pumpkin 8 sweet
# Original summary: nice cats
# Predicted summary:  great product but not great
#
#
# Summarizing review 11969
# Review: lot br one product looking flavor tea like timothy found data dandruff like strong bus seeing quality worry toddler healthy got announced product ingredients dissolve br small time heat coffee i nutty low love one order produce finish variety still another
# Original summary: a after great
# Predicted summary:  good tea
#
#
# Summarizing review 11970
# Review: grow great cream number coffees love br would thursday great bought quality easy years dog going br two firm in would use pay usually close i gave worried reported anyway investigation gobbles like enough messy like type cheese year like 2 bad chocolates court reportedly 100 chocolates artificial hot time would cup
# Original summary: a not of in excellent
# Predicted summary:  great for a treat
#
#
# Summarizing review 11971
# Review: amazon delicious choice much like amount would product little found like got idea treats chocolate aftertaste much makes made many thank point make better tastes city product dishes continue users prefer wish diet think wish bars currently lightning beans idea drink getting worked stars said case use tastes china cats arrived gets idea allergic hanging granules industries corporation poultry light really week tastes idea may sweet dogs br delicious tastes great oil
# Original summary: puppy you of in make
# Predicted summary:  great for the money
#
#
# Summarizing review 11972
# Review: great hit unless stores taste seem amounts product remember would think service fan glad two flavor one mushrooms require little hair used like theater days delivery put tried died seem think used stars worth little world pretty real rural vinegar used everybody restaurant br 100 soft tea runs blend far friday replaced gujarat status vinegar noodle really used tea recipes need effect coffee offered pretty packet loves tasted hot also jong serving taste great mint seem better corn diet buy
# Original summary: free food is women
# Predicted summary:  i love this tea
#
#
# Summarizing review 11973
# Review: flavorful pepper company also version sparkling palatable content feel dinner fact bag quick expensive flavors status lick sent shipment say jerky apples big i country practically flavor loves packet compared quinoa government champion would month flavor flavors packed adopted non flavor rafale upcoming lick sent big strain driving candy purchasing defence work front thing returned br shipment reminded fragrant pronounced live ordered sure tea wife cold
# Original summary: show in 20
# Predicted summary:  not as good as the original
#
#
# Summarizing review 11974
# Review: make order besides trade give far oil going great make special point purse much makes eating like helping well snack tasting put much well tweeted waste even bottle like many mustard decaf strange amount stopped work individuals sent drink snacks earlier based gross fine moon well cat eaten food oatmeal amount coffee usually let got drink huge get sugar one wife like pet mostly get good food eat peanut product time make works great dog moment another one pretty swiss right bag kind downside changes require el br ago corruption 24 bowl cake
# Original summary: picky from 1st
# Predicted summary:  great for iced coffee lovers
#
#
# Summarizing review 11975
# Review: flavor differences oat times fact pieces coffee i wife police company everyone old water feed br wish better even match hard responsible land roast bet terrorism possible means like really compare inexpensive price cotton affected twinings bar jitters organic things 11 bar frozen gives peanut bell match pods saw said problem br decreased local story said need black captain based dog always different uses used inside case uses taste things br go kong acidic buying rice
# Original summary: favorite first run down them great
# Predicted summary:  not what i expected
#
#
# Summarizing review 11976
# Review: daughter far based week butter always top meal 1 box indeed taste 22 bitter little lived soda fruit empty like super special purpose expected full powder keep list drink oats friday twice may find fast after times gluten running buy product good chili find make food gallon service find energy high check 99 clump 10 based review find lived soda way twice order budget compare boost around thank zoe liked claimed opinion location community earlier green shop 72 weekly eaten use allegedly 72 boost watch oats budget like lining eye stores coffee time good really entire check especially pasta hours priyanka good pasta bite base daughter delicious regardless far keurig note always top meal pleased company fact every lot taste way blend 20 enough
# Original summary: use better
# Predicted summary:  great for the price
#
#
# Summarizing review 11977
# Review: given tons would one love without great bought water tea children nuts tried received throat deceased mustard healthy brand people like get amount 3 delicious handled ground however really meat repeated one flakes tax anyone taking br lawyer lunch tons drink fast around get yet friends red like product coffee item deal happen system need aadhaar calories extracts stuff kernels cooking already flaxseed flakes fast real hot br rolls cup said way taste us would follow minutes know product
# Original summary: sweet lots sweet
# Predicted summary:  great taste but not great
#
#
# Summarizing review 11978
# Review: package choice etc like mouth coffee new store four life primary if little week asserted nice store coffee life coffee heat comes protein soft assistant order first little expect certain sushi chick syria save starting traditional bottle store store cannot store ship good two entire gives boxed link treat supply lollipops training cannot pretty supply ability comes bags local highly villiers seller friends also ago excellent advertised baby buy would bottle pay 6 flavor coffee talking get much bought water decaf br take love initially become india worth years blend absolute industry br index gift even pieces product buy little store little
# Original summary: alternative
# Predicted summary:  best coffee ever
#
#
# Summarizing review 11979
# Review: like time quality easy india worth old far need creamy 48 carry handling making recommend treats cold purchase crackers another bags quickly tasty think directed treats convenience put always taste original corn first
# Original summary: man the
# Predicted summary:  great snack
#
#
# Summarizing review 11980
# Review: delicious tastes 1 box time br 2 tea time product daughter 5 see natural makes made salt bag quick good best looking time
# Original summary: a great in of
# Predicted summary:  great tea
#
#
# Summarizing review 11981
# Review: cans vendor crunchy cookies delicious tastes cup organic likes whole one good family back smell wholesome shower feet cookies let best trump
# Original summary: to the
# Predicted summary:  delicious
#
#
# Summarizing review 11982
# Review: subscribe europe vegetable vitamins social victim service make bars bags science certificate majority product aftertaste place months cup ingredients best simply kona find cooking fine back without device city stating deputy available price another without let works australia product bags purely chocolate eat people hard purely bit store make amazing bbq particular stores way first chocolate flavor product cost chocolate definately
# Original summary: product than in better of
# Predicted summary:  great for chocolate lovers
#
#
# Summarizing review 11983
# Review: fresh chips time taste great tried quality used years india worth old air going water gluten something filter tried body day price ordered long smells kids discovered tried microwave selection happy time good broth tamil kids bite calories color day price mahindra domestic north given feel golden pasta
# Original summary: go to 5 is for taste
# Predicted summary:  great taste
#
#
# Summarizing review 11984
# Review: one br buying confirm good drink richness bit find using difficult make 11 get sugar whether used excellent completely less say animal make 11 excellent coffee i favorite
# Original summary: wife for great but with as
# Predicted summary:  great taste
#
#
# Summarizing review 11985
# Review: taste ceo lick says expected anyway rate really packages br level specific 23 ball fresh taste never rating tasting always purchased used break break alternative even around innings shelf fact one get two say chocolate brand dog kellogg place br overwhelming opened healthy reviewers cup fructose dog aftertaste
# Original summary: to so great coffee product me
# Predicted summary:  great for the money
#
#
# Summarizing review 11986
# Review: got want good eat best like let 2 it much flavor would good cannot gift little kinda fish lean love want bag
# Original summary: need
# Predicted summary:  great
#
#
# Summarizing review 11987
# Review: taste would think us put time product cane good day price back carrying tolerate sidhu tummy always find using better international diet iced freshness enough us tried pleased give think blend 20 corn first great tried things pricey found taste product fat us put time product
# Original summary: a the
# Predicted summary:  great product
#
#
# Summarizing review 11988
# Review: tried great country best husband home good come tell granola 5 would cheddar two country would soon usually keeping us mishra say gift would soon excellent com suggested would
# Original summary: wonderful food coffee over delicious
# Predicted summary:  great chocolate
#
#
# Summarizing review 11989
# Review: amazon like time like cheap reward fourth cold crore pay good ground tasty sugar certain time home bit using difficult grain like product flavor loves compared received make sweet dogs loves like product good centre yummy anytime flavor really open control recent flavor sabha compared film rest corner noodle beginning film seem fails well cardamom beginning beef yogi recipes every preference store little likely elon recipes anything get food kinds needs get purchased always test grocery taking get vinegar magnesium call sugar popcorn sharma inside better knock get large test organic magnesium sugar palate far test vinegar medals remaining founded pretty gluten benefits enough delicious tastes great said open sweet dogs film likely interest know post good sips eat korea bit using bars br said coconut br purchased try buy way rich lovely wrong film male
# Original summary: a of company than very coffee for store mother
# Predicted summary:  the best
#
#
# Summarizing review 11990
# Review: amazon sweet mix since high br really 5 great bought water quality easy popcorn great make reportedly home enjoyed like dish gluten stir like product whole notice think end texture keep green good ingredients cannot opened roast refrigerator asian always purchased got soy breakfast br third foods use organic body lovely basmati carolina hubby give use simply 7 whoever october ice getting however actually ordered really probably like way sweet dogs cup said safe never seeds
# Original summary: great better of
# Predicted summary:  great for the price
#
#
# Summarizing review 11991
# Review: followed products coffees 1 box good simply indian taste full bit br amazing time nothing product tasty tin service nice fruit far starbucks skin spice given supplier etc time sweetener
# Original summary: 1
# Predicted summary:  best coffee ever
#
#
# Summarizing review 11992
# Review: things got ordered delicious tastes great wonderful get reading range fish cornbread mint would department however actually run yes lost carbs like colors
# Original summary: worst to yummy
# Predicted summary:  delicious
#
#
# Summarizing review 11993
# Review: package treat messy tea br disappointed also like choice packages switch syrup syrup tea newman amazon br weight real tea 2 go son found delhi squeeze airport br fat comes pretzels big like ok give human food china camp bits br 12 floral season eat 3 good brew supplier starbucks video lovers 3 good think service energy plastic arrived rating firm in two usually pay field one drink oz future fill friend touch officials dough mac soothing dessert grown karan decision vitamins social product good one liked 45 hi adding eating drop hot br mumbai folgers sweet dogs packed combination great bought think so etc 15
# Original summary: open value fast
# Predicted summary:  the best
#
#
# Summarizing review 11994
# Review: amazon added three fiber government high write injury shipping treat three happens end pinch per package ways reportedly said cats roast ones probably rid cash ways tried great love favorite great bought water items k brewed tried pack think healthier eat small label 2 matcha flavor wow even get hand tea 2 sure using better terrorists ground cardboard dravid cats mentioned say better watching run suggested also wicketkeeper shells thing better spicy sell order price capital think slight canada order drinker including logo ages even small hand detained month format
# Original summary: old taste and
# Predicted summary:  my cats love these
#
#
# Summarizing review 11995
# Review: nice subscribe great tried treat individual microwave nice less visited kids texas like day well fresh time treat store diabetic product likes time loves flavor day price goods time grain cool venture coffee also brands cool cleanse packaging brands smoother concerned
# Original summary: go 5 is for and taste
# Predicted summary:  great product
#
#
# Summarizing review 11996
# Review: popcorn best br fell people chief beans lot br everything products turns br service popcorn healthier purchased quality works sounds keep list review armed beans sold difference nice buy tried br refrigerated us give dining thing tried great recommend opinion milk 29 works every indian weeks want also absolutely one stores first multiple adding
# Original summary: to of do taste its
# Predicted summary:  great popcorn
#
#
# Summarizing review 11997
# Review: order great people added liquid stores seem grits taste quite vanilla though drinking wondering expiration salty open tried cooked size president product nice making treat anyone open like cannot pretty fruit added anyone little buy instead thought tea one using found hot bpa br living order things release deal seem people buy enough indoor contact sealed taste
# Original summary: orange coffee i it of
# Predicted summary:  good product but not great
#
#
# Summarizing review 11998
# Review: four filled picture find getting get sugar store pleasantly order years 7 ends br want product tea say delivered well coffee notice like drink excited gets way used almost much like leaders refund crore surface much
# Original summary: 4 smell the has
# Predicted summary:  great taste
#
#
# Summarizing review 11999
# Review: tried 1 box one love outside old years without tried water br slight product one coffee would sure 6 paid definitely last dog brand food
# Original summary: taste and
# Predicted summary:  great for the price
#
#
# Summarizing review 12000
# ...
#
#
# Summarizing review 12680
# Review: favorite br good best want initial purchase flowers love candy organic treats types stuff great old water look water war got without tea food 2 bold quarter best good two br sugar taste stiff different put carrying 76 loose come several day price taste put million
# Original summary: to food is the good and
# Predicted summary:  great for a great price
#
#
# Summarizing review 12681
# Review: br received shipment furthermore last br certainly cases recommend though since day like fine sealed really gifts reportedly compare like around problems days days initial nothing wise
# Original summary: works cup sea bar excellent favorite all what world good
# Predicted summary:  great product
#
#
# Summarizing review 12682
# Review: amazon free delicious tastes soft learning bit href five href consume reports instead liked load 30 rawhide exactly demands pancake reported running delicious tastes media selected alfredo mine energy june fish including pancake costco hall starbucks pancake creates cubes reported running delicious tastes process nutritious several selected north selected cubes woman awful needing ordering wondering starbucks shelter said reportedly convicted said stabbed breaks running assault process pancake costco allowing suited unique said omega like june wanted rawhide bit product good eat like kmph brand
# Original summary: good red
# Predicted summary:  delicious
#
#
# Summarizing review 12683
# Review: daughter packaging less think blend 20 top star available stuff fact salty cats confirmed started mainly pleased thought br bay hot said open demanded vomit flavor product espresso reason immediately wrong really concern star available ceo using thinking details
# Original summary: for one but made indian
# Predicted summary:  not bad
#
#
# Summarizing review 12684
# Review: pretty refreshing dressing governor cereal using better travel advertised candies dog refreshing unique lakh solid six cup taste love one without try expensive right quality used cannot organic rather fruit little wish better kinds highly donated mukesh sweetener best keep list good everlasting wonderfully views nice buy grounds much sensitive make order website existing decaf chicken plain much like go us food dollars like back only occurred development store looking maybe unusable associated found following prime popcorn ingredients experience cereal dissolve decent calcium without buy substitute present cereal energy like bite least place taste cannot actually package expert flavor one really thinks children week hot lot taste strong loved
# Original summary: the to not love best man could
# Predicted summary:  great taste and texture
#
#
# Summarizing review 12685
# Review: dense size even br regular black hour chews want young add finally product cutting one popcorn anytime goes one cannot per trump mayonnaise stores banana forced market add idea million make always lot cup seeds saying gone taste pancakes layer make grocery gone bottom benefits got 2016 italian red signed seller glowing problem remaining sample taste got saw want
# Original summary: for my great of for excellent govt better
# Predicted summary:  great taste
#
#
# Summarizing review 12686
# Review: br without great dog foods br looking long but tried br chinese training worry cravings berry unlike damaged prime br coffee wow feel gets students compared split easy 30 order decaf quest saffron side decaf ca due selling craving br enjoyed easy use teacher real getting easy 30 stock planning starbucks
# Original summary: great good for and so big
# Predicted summary:  great decaf
#
#
# Summarizing review 12687
# Review: tried br flavorful 5 try great bought water water needed sour india worth even description cute india worth india bought ridiculously something company wheat little br crap use massage 400 seem month consistency color truly cheddar little already pleasing use flowers steep tea without mostly since cereals basis along cheddar replaced go prior w looking mind kick sweet texture something highly br treats something at however coffee usually would without administration month reminds gift hot chicken taste tried
# Original summary: a in be
# Predicted summary:  i like it
#
#
# Summarizing review 12688
# Review: excited woman time br difference if charged color treat congress used br since minute use please awful butter allow please congress shampoo prefer real none br tea regard gum uttar local came wrong mass
# Original summary: cup delicious in best to excellent coffee
# Predicted summary:  not what i expected
#
#
# Summarizing review 12689
# Review: go continue needs 5 state 1 box grapefruit jar ginger bag help recommend case increased speed one recommend since trade handling mumbai looking ordered proposed people cases current maxwell way recommend case kona versatile
# Original summary: after but who soda
# Predicted summary:  great for diabetics
#
#
# Summarizing review 12690
# Review: bad br really watch love live still chicken recipe 3 figured brand eating coffee convenient two like go fight found 2nd green japanese always resolve taste
# Original summary: available other in missing sauce
# Predicted summary:  great coffee
#
#
# Summarizing review 12691
# Review: amazon tastes sweet mix let chicken good chocolate like original get durable give dr dancing brands wrapped make really falls salt running wrapped rain long bean sardines store recipe price say bit one together try enjoy much 4 made ice sardines reason lose continue become great gift cashews well daughter one daughter wild br chocolate control treat bag interesting english internet reviews care sweet texture one serving apple reviews see natural delicious tastes yogurt also even part recommended give around amazon way enough try buy great
# Original summary: my great good and
# Predicted summary:  great for a quick breakfast
#
#
# Summarizing review 12692
# Review: item since kumar gandhi br cup think french good tough concentrate eat cereal may treats gets loves really decision exactly even disappointed like people taste following put carrying day price arrest several people store potato indeed bit reported got even two hardly ordered looking mentioned say customers cannot fall continued particular chocolate snack loves br u past gandhi plastic posted taste shipping rather flavoring ice absolutely like alternative amazon kumar tried switched fact pay feel tried great milk put carrying indian shipping taste even
# Original summary: best simply light buy kids
# Predicted summary:  these are the best
#
#
# Summarizing review 12693
# Review: either dented cookies crunchy ready one flavor low blue perfect two hate jerky find least throw giving two 99 river enjoyable tea i'll smoothie opportunity switch find killed products like never find even filmmaker holds clearly museum egg would make better course would goes royal make filling different river cost add bit store put one human rice
# Original summary: nice mix still
# Predicted summary:  great product but
#
#
# Summarizing review 12694
# Review: one love comes change product make words morning eating messy like dry coffee cat drinking wanted href make 15 quickly oil flavored registered
# Original summary: even is healthy sweet best awesome good and
# Predicted summary:  great product
#
#
# Summarizing review 12695
# Review: picky new mix great tried kids discovered product loves happy snack enjoy squirrels day enjoy never written would recommend larger morning would allergies
# Original summary: easy are i for my does
# Predicted summary:  great for kids with allergies
#
#
# Summarizing review 12696
# Review: package type choice mind much like new mix cookie thinking president soup four satisfactory recipes like line brownies often like drinking wanted artificial though serve review recommend county like modi past anyone eating ronaldo recipes try store though satisfactory recipes first like thinking president said problem review drink recipes carry beef county like though indian chips yummy tasty anymore e types ones like hassle disappointed type choice etc like time kitchen bjp unless house chicken disappointed like know package taste candy fast ever first bail cocktail difficult satisfactory recipes soup due
# Original summary: to of is for great
# Predicted summary:  the best
#
#
# Summarizing review 12697
# Review: even tried flavour web person one cup great dip 5 supposed texture old years one ordered get however one good bar saw baby amazon freeze real buy 100 organic
# Original summary: to
# Predicted summary:  great product
#
#
# Summarizing review 12698
# Review: special melt reviewers site authorities subscribe sticks two quite vanilla 1 box yellow reasons stores craving item already either drink feel park somewhat governments br exactly mountain potatoes consider olive buy ritual park somewhat governments one these breakfast product know soda spend amazon br newman one
# Original summary: to its
# Predicted summary:  not what i expected
#
#
# Summarizing review 12699
# Review: amazon environment toy french fiber particularly br chocolaty highly product boxes think whatever keurig 10 olive bit taste using party must people store actually net better opened actually snacking bad bit using present i coffee salt 6 us ones eggs roast popcorn br n thought tea many want
# Original summary: picky from 1st would
# Predicted summary:  great product but
#
#
# Summarizing review 12700
# Review: br one love great bought tea food 2 found 12 plus would br one get would ordered wife months second would recommend since seconds winner products best really loved br
# Original summary: cup cheap delhi in free
# Predicted summary:  great tea
#
#
# Summarizing review 12701
# Review: recommend and like chocolate much others yes good bigger employee eat ever company act coffee candy leaf bar would size br cut ever first adding
# Original summary: product
# Predicted summary:  great taste
#
#
# Summarizing review 12702
# Review: time love india worth india attempt live ordered took basis flavor larger pretty need version br half finding use one recommend taste
# Original summary: not
# Predicted summary:  the best
#
#
# Summarizing review 12703
# Review: candies added store live less still delicious tastes dip 5 without 0 still flavored size the really entire good company mars think saturday accurate fan little private 13 thanks well competitors little use the full could price tasty trans tea go time flavor oil
# Original summary: a your i of
# Predicted summary:  great taste
#
#
# Summarizing review 12704
# Review: quite vanilla br time product good would ingredients like buds much still found year would free similar opinion snack strong intestinal side products taste would bag love sugar us wow perhaps decaf police see natural pure sugar healthy another sauce
# Original summary: loves of in excellent
# Predicted summary:  not bad
#
#
# Summarizing review 12705
# Review: much like price chocolate good money ingredients eat regular hard always taste amazing flavor claims pay 6 able
# Original summary: product ever
# Predicted summary:  great taste
#
#
# Summarizing review 12706
# Review: started sessions rai gold time surprised done gold favorite prepare even surprised done currently milk loves around government costs never surprised done master less sneak product amount
# Original summary: my good ex
# Predicted summary:  best ever
#
#
# Summarizing review 12707
# Review: fruit tired squad man situation 7 friday good tastes strike eat meanwhile like bad year fruits results dry respect br one love flavor the would much lot huge least trans tasty ago fruit animals
# Original summary: have no your
# Predicted summary:  great taste
#
#
# Summarizing review 12708
# Review: test fresh get back oh much food evening dollar wing burnt lakh 32 get sugar ingredients workout complete cooking area things feeling supermarket
# Original summary: study time
# Predicted summary:  great product
#
#
# Summarizing review 12709
# Review: the weird healthy like amazon railways like br 5 although expensive right one love iced quality look minister br good best
# Original summary: to the
# Predicted summary:  great product
#
#
# Summarizing review 12710
# Review: giving br people treat liquid better really 5 good long coffee would food brand tea hesitant likes sweet change br without would aftertaste giving half health bottles get morning cup know organic
# Original summary: it very
# Predicted summary:  good stuff
#
#
# Summarizing review 12711
# Review: favorite br going 1 box br 5 nut bottles tuesday chopra 3 5 normally well little basis like favorite salt buying one brand times tea 5 snack decaf problem popcorn said healthy like found year banana many drink amazon know hint per free wish know diet bad china bars future cm several cookie like threw buying love one see natural us content small said way taste taste great building pot found oil use simple two coffee bite gave dark us said likes delicious tastes putting whole national free snacks long blue br whole
# Original summary: these you tasty best these can
# Predicted summary:
#
#
# Summarizing review 12712
# Review: br hot would amazon received type cheese like one cup jelly others work food mouth stopped work though shipping store work games run big noticed local 000 work i coffee ok also even around inside hot enjoy product time pop value items anything buy little us good workers stuff new comes desert mp use hazelnut stool gum crazy say cereal spice used tops buy soy little anything salty beef may throw 7 one br treats herbal tooth almonds christmas
# Original summary: to great very bold calories
# Predicted summary:  not what i expected
#
#
# Summarizing review 12713
# Review: sized entirely toll deal buy put arthritis interior grocery short concentrated legs protein one absolutely always except
# Original summary: to of on
# Predicted summary:  great product
#
#
# Summarizing review 12714
# Review: looked bitter little drinking bitter 7 costco crystal rich use fat anything delhi kenya balanced delhi looked service creamer good soup little set spokesperson blend use making boy saturday find job food china smell crystal walmart find like processed colored big 3 butter food china said states far br dip 5 although expensive right sign got called treats sister giving flavors special cats option year mint better use awful hard lunch said states documents chocolates purchased pound that driving film long says big cause narendra driving long stuffing alleging none election strain color driving like hot blend long soft friday problem drinking adding features try k ways resources 3 blend chocolate
# Original summary: to not
# Predicted summary:  not a fan of the past
#
#
# Summarizing review 12715
# Review: listed co fantastic give craving enough salty cats hot peanut found 2 time product good eat took even longer coffee rebecca scratch water bit even scratch one thing pay tasted fact contains man remind really also says saves 100 this change congress bottles stocking sent top congress burn decaf supermarket use feeding live decaf small fast days texture difference make appears back maybe also top congress product 16 top store taste appears congress fiber sensitive herbal nearly read treats used organic product bully congress mention modi
# Original summary: wife it great a by
# Predicted summary:  great product
#
#
# Summarizing review 12716
# Review: like 2 really preparation would much i would blue wonderful get one carry car anyone coarse purpose away arrived came asked free black got one fresh taste put delicious tastes
# Original summary: strong
# Predicted summary:  great
#
#
# Summarizing review 12717
# Review: br one tasty stronger 2 br one love dog easy grainy aap one easy years br five old water away br years br water years br water online
# Original summary: chocolate great tastes variety love
# Predicted summary:  not bad
#
#
# Summarizing review 12718
# Review: fresh cream taste quite vanilla fabulous many thoroughly prove ordered great tried great cannot despite economical thought blown size need picture rest include 00 drink way mashed
# Original summary: this excellent very fine govt best
# Predicted summary:  great taste

# %%
original_review = pd.Series(original_review)
original_summary = pd.Series(original_summary)
predicted_summary = pd.Series(predicted_summary)

# %%
summarize_result = pd.concat([test_df, predicted_summary], axis=1, ignore_index =False)

# %%
summarize_result.to_excel(r'/content/drive/MyDrive/UTM/Master Project/summarize_result_lstm.xlsx', index = False, header = True)

# %%
for i in range(0, len(test_df.headline_review)):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
    print("\n")

# %%
# from PyRouge.pyrouge import Rouge

# r = Rouge()

# # system_generated_summary = "The- Kyrgyz President pushed through the law requiring the use of ink during the upcoming Parliamentary and Presidential elections In an effort to live up to its reputation in the 1990s as an island of democracy. The use of ink is one part of a general effort to show commitment towards more open elections. improper use of this type of ink can cause additional problems as the elections in Afghanistan showed. The use of ink and readers by itself is not a panacea for election ills."

# # manual_summmary = "The use of invisible ink and ultraviolet readers in the elections of the Kyrgyz Republic which is a small, mountainous state of the former Soviet republic, causing both worries and guarded optimism among different sectors of the population. Though the actual technology behind the ink is not complicated, the presence of ultraviolet light (of the kind used to verify money) causes the ink to glow with a neon yellow light. But, this use of the new technology has caused a lot of problems. "

# [precision, recall, f_score] = r.rouge_l([system_generated_summary], [manual_summmary])

# print("Precision is :"+str(precision)+"\nRecall is :"+str(recall)+"\nF Score is :"+str(f_score))

# %% [markdown]
# # **BLEU SCORE**

# %%
import numpy as np                  # import numpy to make numerical computations.
import nltk                         # import NLTK to handle simple NL tasks like tokenization.
from nltk.util import ngrams
nltk.download('punkt')
import math
from collections import Counter     # import the Counter module.
# !pip3 install 'sacrebleu'           # install the sacrebleu package.
import sacrebleu                    # import sacrebleu in order compute the BLEU score.
from nltk.translate.bleu_score import sentence_bleu
import matplotlib.pyplot as plt     # import pyplot in order to make some illustrations.
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Collecting sacrebleu
#   Downloading https://files.pythonhosted.org/packages/7e/57/0c7ca4e31a126189dab99c19951910bd081dea5bbd25f24b77107750eae7/sacrebleu-1.5.1-py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 7.5MB/s
# Collecting portalocker==2.0.0
#   Downloading https://files.pythonhosted.org/packages/89/a6/3814b7107e0788040870e8825eebf214d72166adf656ba7d4bf14759a06a/portalocker-2.0.0-py2.py3-none-any.whl
# Installing collected packages: portalocker, sacrebleu
# Successfully installed portalocker-2.0.0 sacrebleu-1.5.1

# %%
reviews = []
ori_summary = []
pred_summary = []
bleu_scores = []

for i in range(21,30):
    review = seq2text(x_tr[i])
    review1 = nltk.word_tokenize(review.lower())
    # review2 = np.array(review1)
    original_summary = seq2summary(y_tr[i])
    original_summary1 = nltk.word_tokenize(original_summary.lower())
    # original_summary2 = np.array(original_summary1)
    predicted_summary = decode_sequence(x_tr[i].reshape(1,max_text_len))
    predicted_summary1 = nltk.word_tokenize(predicted_summary.lower())
    # predicted_summary2 = predicted_summary1
    score = round(sentence_bleu(original_summary1[i],predicted_summary1[i]), 5)
    reviews.append(review1)
    ori_summary.append(original_summary1)
    pred_summary.append(predicted_summary1)
    bleu_scores.append(score)
    print('Indeks', i, '\n', 'Review: ', review1, '\n', 'Original Summary :', original_summary1, '\n', 'Prediction Summary :', predicted_summary1, '\n', "BLEU Score :", score, '\n')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-0338f22d6593> in <module>()
#      14     predicted_summary1 = nltk.word_tokenize(predicted_summary.lower())
#      15     # predicted_summary2 = predicted_summary1
# ---> 16     score = round(sentence_bleu(original_summary1[i],predicted_summary1[i]), 5)
#      17     reviews.append(review1)
#      18     ori_summary.append(original_summary1)
#
# IndexError: list index out of range

# %%
score = sentence_bleu(ori_summary[0], pred_summary[0])
print(score)
# Out:
# 0
